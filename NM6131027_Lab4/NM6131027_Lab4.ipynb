# %% [markdown]
# # Knowledge Distillation
# - The concept of **knowledge distillation** is to utilize class probabilities of a higher-capacity model (teacher) as soft targets of a smaller model (student)
# - The implement processes can be divided into several stages:
#   1. Finish the `ResNet()` classes
#   2. Train the teacher model (ResNet50) and the student model (ResNet18) from scratch, i.e. **without KD**
#   3. Define the `Distiller()` class and `loss_re()`, `loss_fe()` functions
#   4. Train the student model **with KD** from the teacher model in two different ways, response-based and feature based distillation
#   5. Comparison of student models w/ & w/o KD

# %% [markdown]
# ## Setup

# %%
! pip install torchinfo
# Out:
# Requirement already satisfied: torchinfo in c:\users\nm6131027\appdata\local\anaconda3\envs\aicup-gpu\lib\site-packages (1.8.0)

# %%
import torch
from torch import nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms, models
from torch.utils.data import DataLoader, Dataset, random_split
from torchinfo import summary
from tqdm import tqdm
import sys
import numpy as np
import math
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
torch.manual_seed(0)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
torch.backends.cudnn.benchmark = True

# %% [markdown]
# ## Download dataset

# %%
validation_split = 0.2
batch_size = 128

# data augmentation and normalization
transform_train = transforms.Compose([
                    transforms.RandomCrop(32, padding=4),
                    transforms.RandomHorizontalFlip(),
                    transforms.ToTensor(),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))])

transform_test = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# download dataset
train_and_val_dataset = torchvision.datasets.CIFAR10(
    root='dataset/',
    train=True,
    transform=transform_train,
    download=True
)

test_dataset = torchvision.datasets.CIFAR10(
    root='dataset/',
    train=False,
    transform=transform_test,
    download=True
)

# split train and validation dataset
train_size = int((1 - validation_split) * len(train_and_val_dataset))
val_size = len(train_and_val_dataset) - train_size
train_dataset, val_dataset = random_split(train_and_val_dataset, [train_size, val_size])

# create dataLoader
train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

test_num = len(test_dataset)
test_steps = len(test_loader)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to dataset/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:14<00:00, 11.9MB/s]
# Extracting dataset/cifar-10-python.tar.gz to dataset/
# Files already downloaded and verified

# %% [markdown]
# ## Create teacher and student models
# ### Define BottleNeck for ResNet50

# %%
class BottleNeck(nn.Module):
    expansion = 4

    def __init__(self, in_channel, out_channel, stride=1, downsample=None, **kwargs):
        super(BottleNeck, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channel, out_channels=out_channel, kernel_size=1, stride=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.conv2 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.conv3 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel * self.expansion, kernel_size=1, stride=1, bias=False)
        self.bn3 = nn.BatchNorm2d(out_channel * self.expansion)
        self.relu = nn.ReLU(inplace=True)
        self.downsample = downsample

    def forward(self, x):
        identity = x
        if self.downsample is not None:
            identity = self.downsample(x)

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu(out)

        out = self.conv3(out)
        out = self.bn3(out)

        out += identity
        out = self.relu(out)

        return out

# %% [markdown]
# ### Define Resifual Block

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_channel, out_channel, stride=1, downsample=None, **kwargs):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=in_channel, out_channels=out_channel, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(out_channel)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=out_channel, out_channels=out_channel, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(out_channel)
        self.downsample = downsample

    def forward(self, x):
        identity = x
        if self.downsample is not None:
            identity = self.downsample(x)

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        out += identity
        out = self.relu(out)

        return out

# %% [markdown]
# ### Define ResNet Model

# %%
class ResNet(nn.Module):

    def __init__(self, block, blocks_num, num_classes=1000):
        super(ResNet, self).__init__()
        self.in_channel = 64

        self.conv1 = nn.Conv2d(3, self.in_channel, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(self.in_channel)
        self.relu = nn.ReLU(inplace=True)
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
        self.layer1 = self._make_layer(block, 64, blocks_num[0])
        self.layer2 = self._make_layer(block, 128, blocks_num[1], stride=2)
        self.layer3 = self._make_layer(block, 256, blocks_num[2], stride=2)
        self.layer4 = self._make_layer(block, 512, blocks_num[3], stride=2)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')

    def _make_layer(self, block, channel, block_num, stride=1):
        downsample = None
        if stride != 1 or self.in_channel != channel * block.expansion:
            downsample = nn.Sequential(
                nn.Conv2d(self.in_channel, channel * block.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(channel * block.expansion))

        layers = []
        layers.append(block(self.in_channel, channel, downsample=downsample, stride=stride))
        self.in_channel = channel * block.expansion

        for _ in range(1, block_num):
            layers.append(block(self.in_channel, channel))

        return nn.Sequential(*layers)

    def forward(self, x):
        # 1. Finish the forward pass and return the output layer as well as hidden features.
        # 2. The output layer and hidden features will be used later for distilling.
        # 3. You can refer to the ResNet structure illustration to finish it.
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.maxpool(x)

        x = self.layer1(x)
        feature1 = x

        x = self.layer2(x)
        feature2 = x

        x = self.layer3(x)
        feature3 = x

        x = self.layer4(x)
        feature4 = x

        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.fc(x)

        return x, [feature1, feature2, feature3, feature4]

# %% [markdown]
# ### Define ResNet50 and Resnet18

# %%
def resnet18(num_classes=10):
    return ResNet(BasicBlock, [2, 2, 2, 2], num_classes=num_classes)

def resnet50(num_classes=10):
    return ResNet(BottleNeck, [3, 4, 6, 3], num_classes=num_classes)

# %% [markdown]
# ## Teacher Model (ResNet50)

# %%
Teacher = resnet50(num_classes=10)  # commment out this line if loading trained teacher model
# Teacher = torch.load('Teacher.pt', weights_only=False)  # loading trained teacher model
Teacher = Teacher.to(device)

# %%
summary(Teacher)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ResNet                                   --
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# │    └─BottleNeck: 2-1                   --
# │    │    └─Conv2d: 3-1                  4,096
# │    │    └─BatchNorm2d: 3-2             128
# │    │    └─Conv2d: 3-3                  36,864
# │    │    └─BatchNorm2d: 3-4             128
# │    │    └─Conv2d: 3-5                  16,384
# │    │    └─BatchNorm2d: 3-6             512
# │    │    └─ReLU: 3-7                    --
# │    │    └─Sequential: 3-8              16,896
# │    └─BottleNeck: 2-2                   --
# │    │    └─Conv2d: 3-9                  16,384
# │    │    └─BatchNorm2d: 3-10            128
# │    │    └─Conv2d: 3-11                 36,864
# │    │    └─BatchNorm2d: 3-12            128
# │    │    └─Conv2d: 3-13                 16,384
# │    │    └─BatchNorm2d: 3-14            512
# │    │    └─ReLU: 3-15                   --
# │    └─BottleNeck: 2-3                   --
# │    │    └─Conv2d: 3-16                 16,384
# │    │    └─BatchNorm2d: 3-17            128
# │    │    └─Conv2d: 3-18                 36,864
# │    │    └─BatchNorm2d: 3-19            128
# │    │    └─Conv2d: 3-20                 16,384
# │    │    └─BatchNorm2d: 3-21            512
# │    │    └─ReLU: 3-22                   --
# ├─Sequential: 1-6                        --
# │    └─BottleNeck: 2-4                   --
# │    │    └─Conv2d: 3-23                 32,768
# │    │    └─BatchNorm2d: 3-24            256
# │    │    └─Conv2d: 3-25                 147,456
# │    │    └─BatchNorm2d: 3-26            256
# │    │    └─Conv2d: 3-27                 65,536
# │    │    └─BatchNorm2d: 3-28            1,024
# │    │    └─ReLU: 3-29                   --
# │    │    └─Sequential: 3-30             132,096
# │    └─BottleNeck: 2-5                   --
# │    │    └─Conv2d: 3-31                 65,536
# │    │    └─BatchNorm2d: 3-32            256
# │    │    └─Conv2d: 3-33                 147,456
# │    │    └─BatchNorm2d: 3-34            256
# │    │    └─Conv2d: 3-35                 65,536
# │    │    └─BatchNorm2d: 3-36            1,024
# │    │    └─ReLU: 3-37                   --
# │    └─BottleNeck: 2-6                   --
# │    │    └─Conv2d: 3-38                 65,536
# │    │    └─BatchNorm2d: 3-39            256
# │    │    └─Conv2d: 3-40                 147,456
# │    │    └─BatchNorm2d: 3-41            256
# │    │    └─Conv2d: 3-42                 65,536
# │    │    └─BatchNorm2d: 3-43            1,024
# │    │    └─ReLU: 3-44                   --
# │    └─BottleNeck: 2-7                   --
# │    │    └─Conv2d: 3-45                 65,536
# │    │    └─BatchNorm2d: 3-46            256
# │    │    └─Conv2d: 3-47                 147,456
# │    │    └─BatchNorm2d: 3-48            256
# │    │    └─Conv2d: 3-49                 65,536
# │    │    └─BatchNorm2d: 3-50            1,024
# │    │    └─ReLU: 3-51                   --
# ├─Sequential: 1-7                        --
# │    └─BottleNeck: 2-8                   --
# │    │    └─Conv2d: 3-52                 131,072
# │    │    └─BatchNorm2d: 3-53            512
# │    │    └─Conv2d: 3-54                 589,824
# │    │    └─BatchNorm2d: 3-55            512
# │    │    └─Conv2d: 3-56                 262,144
# │    │    └─BatchNorm2d: 3-57            2,048
# │    │    └─ReLU: 3-58                   --
# │    │    └─Sequential: 3-59             526,336
# │    └─BottleNeck: 2-9                   --
# │    │    └─Conv2d: 3-60                 262,144
# │    │    └─BatchNorm2d: 3-61            512
# │    │    └─Conv2d: 3-62                 589,824
# │    │    └─BatchNorm2d: 3-63            512
# │    │    └─Conv2d: 3-64                 262,144
# │    │    └─BatchNorm2d: 3-65            2,048
# │    │    └─ReLU: 3-66                   --
# │    └─BottleNeck: 2-10                  --
# │    │    └─Conv2d: 3-67                 262,144
# │    │    └─BatchNorm2d: 3-68            512
# │    │    └─Conv2d: 3-69                 589,824
# │    │    └─BatchNorm2d: 3-70            512
# │    │    └─Conv2d: 3-71                 262,144
# │    │    └─BatchNorm2d: 3-72            2,048
# │    │    └─ReLU: 3-73                   --
# │    └─BottleNeck: 2-11                  --
# │    │    └─Conv2d: 3-74                 262,144
# │    │    └─BatchNorm2d: 3-75            512
# │    │    └─Conv2d: 3-76                 589,824
# │    │    └─BatchNorm2d: 3-77            512
# │    │    └─Conv2d: 3-78                 262,144
# │    │    └─BatchNorm2d: 3-79            2,048
# │    │    └─ReLU: 3-80                   --
# │    └─BottleNeck: 2-12                  --
# │    │    └─Conv2d: 3-81                 262,144
# │    │    └─BatchNorm2d: 3-82            512
# │    │    └─Conv2d: 3-83                 589,824
# │    │    └─BatchNorm2d: 3-84            512
# │    │    └─Conv2d: 3-85                 262,144
# │    │    └─BatchNorm2d: 3-86            2,048
# │    │    └─ReLU: 3-87                   --
# │    └─BottleNeck: 2-13                  --
# │    │    └─Conv2d: 3-88                 262,144
# │    │    └─BatchNorm2d: 3-89            512
# │    │    └─Conv2d: 3-90                 589,824
# │    │    └─BatchNorm2d: 3-91            512
# │    │    └─Conv2d: 3-92                 262,144
# │    │    └─BatchNorm2d: 3-93            2,048
# │    │    └─ReLU: 3-94                   --
# ├─Sequential: 1-8                        --
# │    └─BottleNeck: 2-14                  --
# │    │    └─Conv2d: 3-95                 524,288
# │    │    └─BatchNorm2d: 3-96            1,024
# │    │    └─Conv2d: 3-97                 2,359,296
# │    │    └─BatchNorm2d: 3-98            1,024
# │    │    └─Conv2d: 3-99                 1,048,576
# │    │    └─BatchNorm2d: 3-100           4,096
# │    │    └─ReLU: 3-101                  --
# │    │    └─Sequential: 3-102            2,101,248
# │    └─BottleNeck: 2-15                  --
# │    │    └─Conv2d: 3-103                1,048,576
# │    │    └─BatchNorm2d: 3-104           1,024
# │    │    └─Conv2d: 3-105                2,359,296
# │    │    └─BatchNorm2d: 3-106           1,024
# │    │    └─Conv2d: 3-107                1,048,576
# │    │    └─BatchNorm2d: 3-108           4,096
# │    │    └─ReLU: 3-109                  --
# │    └─BottleNeck: 2-16                  --
# │    │    └─Conv2d: 3-110                1,048,576
# │    │    └─BatchNorm2d: 3-111           1,024
# │    │    └─Conv2d: 3-112                2,359,296
# │    │    └─BatchNorm2d: 3-113           1,024
# │    │    └─Conv2d: 3-114                1,048,576
# │    │    └─BatchNorm2d: 3-115           4,096
# │    │    └─ReLU: 3-116                  --
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Linear: 1-10                           20,490
# =================================================================
# Total params: 23,520,842
# Trainable params: 23,520,842
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Student Model (ResNet18)

# %%
Student = resnet18(num_classes=10)  # commment out this line if loading trained student model
# Student = torch.load('Student.pt', weights_only=False)  # loading trained student model
Student = Student.to(device)

# %%
summary(Student)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ResNet                                   --
# ├─Conv2d: 1-1                            1,728
# ├─BatchNorm2d: 1-2                       128
# ├─ReLU: 1-3                              --
# ├─MaxPool2d: 1-4                         --
# ├─Sequential: 1-5                        --
# │    └─BasicBlock: 2-1                   --
# │    │    └─Conv2d: 3-1                  36,864
# │    │    └─BatchNorm2d: 3-2             128
# │    │    └─ReLU: 3-3                    --
# │    │    └─Conv2d: 3-4                  36,864
# │    │    └─BatchNorm2d: 3-5             128
# │    └─BasicBlock: 2-2                   --
# │    │    └─Conv2d: 3-6                  36,864
# │    │    └─BatchNorm2d: 3-7             128
# │    │    └─ReLU: 3-8                    --
# │    │    └─Conv2d: 3-9                  36,864
# │    │    └─BatchNorm2d: 3-10            128
# ├─Sequential: 1-6                        --
# │    └─BasicBlock: 2-3                   --
# │    │    └─Conv2d: 3-11                 73,728
# │    │    └─BatchNorm2d: 3-12            256
# │    │    └─ReLU: 3-13                   --
# │    │    └─Conv2d: 3-14                 147,456
# │    │    └─BatchNorm2d: 3-15            256
# │    │    └─Sequential: 3-16             8,448
# │    └─BasicBlock: 2-4                   --
# │    │    └─Conv2d: 3-17                 147,456
# │    │    └─BatchNorm2d: 3-18            256
# │    │    └─ReLU: 3-19                   --
# │    │    └─Conv2d: 3-20                 147,456
# │    │    └─BatchNorm2d: 3-21            256
# ├─Sequential: 1-7                        --
# │    └─BasicBlock: 2-5                   --
# │    │    └─Conv2d: 3-22                 294,912
# │    │    └─BatchNorm2d: 3-23            512
# │    │    └─ReLU: 3-24                   --
# │    │    └─Conv2d: 3-25                 589,824
# │    │    └─BatchNorm2d: 3-26            512
# │    │    └─Sequential: 3-27             33,280
# │    └─BasicBlock: 2-6                   --
# │    │    └─Conv2d: 3-28                 589,824
# │    │    └─BatchNorm2d: 3-29            512
# │    │    └─ReLU: 3-30                   --
# │    │    └─Conv2d: 3-31                 589,824
# │    │    └─BatchNorm2d: 3-32            512
# ├─Sequential: 1-8                        --
# │    └─BasicBlock: 2-7                   --
# │    │    └─Conv2d: 3-33                 1,179,648
# │    │    └─BatchNorm2d: 3-34            1,024
# │    │    └─ReLU: 3-35                   --
# │    │    └─Conv2d: 3-36                 2,359,296
# │    │    └─BatchNorm2d: 3-37            1,024
# │    │    └─Sequential: 3-38             132,096
# │    └─BasicBlock: 2-8                   --
# │    │    └─Conv2d: 3-39                 2,359,296
# │    │    └─BatchNorm2d: 3-40            1,024
# │    │    └─ReLU: 3-41                   --
# │    │    └─Conv2d: 3-42                 2,359,296
# │    │    └─BatchNorm2d: 3-43            1,024
# ├─AdaptiveAvgPool2d: 1-9                 --
# ├─Linear: 1-10                           5,130
# =================================================================
# Total params: 11,173,962
# Trainable params: 11,173,962
# Non-trainable params: 0
# =================================================================

# %% [markdown]
# ## Define training function

# %%
def train_from_scratch(model, train_loader, val_loader, epochs, learning_rate, device, model_name):
    criterion = nn.CrossEntropyLoss()
    params = [p for p in model.parameters() if p.requires_grad]
    optimizer = torch.optim.AdamW(params, lr=learning_rate, weight_decay=5e-4)

    loss = []
    train_error=[]
    val_error = []
    valdation_error = []
    train_loss = []
    valdation_loss = []
    train_accuraacy = []
    valdation_accuracy= []

    for epoch in range(epochs):
        train_loss = 0.0
        valid_loss = 0.0
        train_acc = 0.0
        valid_acc = 0.0
        correct = 0.
        total = 0.
        V_correct = 0.
        V_total = 0.

        model.train()
        train_bar = tqdm(train_loader, file=sys.stdout)
        for step, data in enumerate(train_bar):
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            logits, hidden = model(images)
            loss = criterion(logits, labels)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * images.size(0)
            pred = logits.data.max(1, keepdim=True)[1]
            correct += np.sum(np.squeeze(pred.eq(labels.data.view_as(pred))).cpu().numpy())
            total += images.size(0)
            train_acc =  correct/total
            train_bar.desc = "train epoch[{}/{}]".format(epoch + 1, epochs)

        model.eval()
        with torch.no_grad():
            val_bar = tqdm(val_loader, file=sys.stdout)
            for val_data in val_bar:
                val_images, val_labels = val_data
                val_images, val_labels = val_images.to(device), val_labels.to(device)
                outputs, hidden_outputs = model(val_images)
                loss = criterion(outputs, val_labels)
                valid_loss += loss.item() * val_images.size(0)
                pred = outputs.data.max(1, keepdim=True)[1]
                V_correct += np.sum(np.squeeze(pred.eq(val_labels.data.view_as(pred))).cpu().numpy())
                V_total += val_images.size(0)
                val_bar.desc = "valid epoch[{}/{}]".format(epoch + 1, epochs)

        train_loss = train_loss / len(train_loader.dataset)
        train_error.append(train_loss)
        valid_loss = valid_loss / len(val_loader.dataset)
        val_error.append(valid_loss)
        train_accuraacy.append( correct / total)
        valdation_accuracy.append(V_correct / V_total)

        print('\tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(train_loss, valid_loss))
        print('\tTrain Accuracy: %.3fd%% (%2d/%2d)\tValdation Accuracy: %.3fd%% (%2d/%2d) '% (100. * correct / total, correct, total, 100. * V_correct / V_total, V_correct, V_total))

    torch.save(model, f'{model_name}.pt')
    print(f'{model_name}.pt is saved')

    print('Finished Training')

# %% [markdown]
# ## Define testing function

# %%
def test(model, test_loader ,device, type=None):
    criterion = nn.CrossEntropyLoss()
    acc = 0.0
    test_loss = 0.0

    if type == None:
        model.eval()
    elif type == 'distiller':
        model.eval()
        model.teacher.eval()
        model.student.eval()
    else:
       raise ValueError(f'Error: only support response-based and feature-based distillation')

    with torch.no_grad():
        test_bar = tqdm(test_loader, file=sys.stdout)
        for test_data in test_bar:
            test_images, test_labels = test_data
            test_images, test_labels = test_images.to(device), test_labels.to(device)
            if type == None:
                outputs, features = model(test_images)
                loss = criterion(outputs, test_labels)
            elif type == 'distiller':
                outputs, loss = model(test_images, test_labels)
            else:
                raise ValueError(f'Error: only support response-based and feature-based distillation')

            predict_y = torch.max(outputs, dim=1)[1]
            acc += torch.eq(predict_y, test_labels.to(device)).sum().item()
            test_loss += loss.item()
            test_bar.desc = "test"

    test_accurate = acc / test_num
    print('test_loss: %.3f  test_accuracy: %.3f' %(test_loss / test_steps, test_accurate * 100))
    return test_loss / test_steps, test_accurate * 100.

# %% [markdown]
# ## Train Teacher and Student model from scratch

# %%
# Decide the epochs and learning rate
train_from_scratch(Teacher, train_loader, val_loader, epochs= 50 , learning_rate= 1e-3 , device=device, model_name="Teacher")
# Out:
# train epoch[1/50]: 100%|██████████| 313/313 [00:17<00:00, 18.34it/s]
# valid epoch[1/50]: 100%|██████████| 79/79 [00:02<00:00, 34.16it/s]
# 	Training Loss: 0.338919 	Validation Loss: 0.442719
# 	Train Accuracy: 88.470d% (35388/40000)	Valdation Accuracy: 85.480d% (8548/10000)
# train epoch[2/50]: 100%|██████████| 313/313 [00:16<00:00, 18.88it/s]
# valid epoch[2/50]: 100%|██████████| 79/79 [00:02<00:00, 34.06it/s]
# 	Training Loss: 0.240642 	Validation Loss: 0.437250
# 	Train Accuracy: 91.593d% (36637/40000)	Valdation Accuracy: 86.060d% (8606/10000)
# train epoch[3/50]: 100%|██████████| 313/313 [00:16<00:00, 18.87it/s]
# valid epoch[3/50]: 100%|██████████| 79/79 [00:02<00:00, 34.29it/s]
# 	Training Loss: 0.210331 	Validation Loss: 0.443833
# 	Train Accuracy: 92.657d% (37063/40000)	Valdation Accuracy: 86.330d% (8633/10000)
# train epoch[4/50]: 100%|██████████| 313/313 [00:16<00:00, 18.92it/s]
# valid epoch[4/50]: 100%|██████████| 79/79 [00:02<00:00, 34.06it/s]
# 	Training Loss: 0.201623 	Validation Loss: 0.449541
# 	Train Accuracy: 93.080d% (37232/40000)	Valdation Accuracy: 85.730d% (8573/10000)
# train epoch[5/50]: 100%|██████████| 313/313 [00:16<00:00, 18.93it/s]
# valid epoch[5/50]: 100%|██████████| 79/79 [00:02<00:00, 34.51it/s]
# 	Training Loss: 0.194079 	Validation Loss: 0.446692
# 	Train Accuracy: 93.210d% (37284/40000)	Valdation Accuracy: 86.390d% (8639/10000)
# train epoch[6/50]: 100%|██████████| 313/313 [00:16<00:00, 18.88it/s]
# valid epoch[6/50]: 100%|██████████| 79/79 [00:02<00:00, 34.31it/s]
# 	Training Loss: 0.183689 	Validation Loss: 0.438651
# 	Train Accuracy: 93.507d% (37403/40000)	Valdation Accuracy: 86.870d% (8687/10000)
# train epoch[7/50]: 100%|██████████| 313/313 [00:16<00:00, 18.87it/s]
# valid epoch[7/50]: 100%|██████████| 79/79 [00:02<00:00, 33.87it/s]
# 	Training Loss: 0.180235 	Validation Loss: 0.401301
# 	Train Accuracy: 93.703d% (37481/40000)	Valdation Accuracy: 87.220d% (8722/10000)
# train epoch[8/50]: 100%|██████████| 313/313 [00:16<00:00, 18.75it/s]
# valid epoch[8/50]: 100%|██████████| 79/79 [00:02<00:00, 34.07it/s]
# 	Training Loss: 0.171570 	Validation Loss: 0.426433
# 	Train Accuracy: 94.095d% (37638/40000)	Valdation Accuracy: 87.080d% (8708/10000)
# train epoch[9/50]: 100%|██████████| 313/313 [00:16<00:00, 18.76it/s]
# valid epoch[9/50]: 100%|██████████| 79/79 [00:02<00:00, 34.38it/s]
# 	Training Loss: 0.163652 	Validation Loss: 0.418806
# 	Train Accuracy: 94.392d% (37757/40000)	Valdation Accuracy: 86.760d% (8676/10000)
# train epoch[10/50]: 100%|██████████| 313/313 [00:16<00:00, 18.87it/s]
# valid epoch[10/50]: 100%|██████████| 79/79 [00:02<00:00, 33.65it/s]
# 	Training Loss: 0.158239 	Validation Loss: 0.448827
# 	Train Accuracy: 94.407d% (37763/40000)	Valdation Accuracy: 86.480d% (8648/10000)
# train epoch[11/50]: 100%|██████████| 313/313 [00:16<00:00, 18.84it/s]
# valid epoch[11/50]: 100%|██████████| 79/79 [00:02<00:00, 34.07it/s]
# 	Training Loss: 0.153782 	Validation Loss: 0.446053
# 	Train Accuracy: 94.615d% (37846/40000)	Valdation Accuracy: 87.310d% (8731/10000)
# train epoch[12/50]: 100%|██████████| 313/313 [00:16<00:00, 18.81it/s]
# valid epoch[12/50]: 100%|██████████| 79/79 [00:02<00:00, 34.14it/s]
# 	Training Loss: 0.151789 	Validation Loss: 0.422366
# 	Train Accuracy: 94.670d% (37868/40000)	Valdation Accuracy: 86.870d% (8687/10000)
# train epoch[13/50]: 100%|██████████| 313/313 [00:16<00:00, 18.86it/s]
# valid epoch[13/50]: 100%|██████████| 79/79 [00:02<00:00, 34.06it/s]
# 	Training Loss: 0.145859 	Validation Loss: 0.418323
# 	Train Accuracy: 94.933d% (37973/40000)	Valdation Accuracy: 87.470d% (8747/10000)
# train epoch[14/50]: 100%|██████████| 313/313 [00:16<00:00, 18.76it/s]
# valid epoch[14/50]: 100%|██████████| 79/79 [00:02<00:00, 34.20it/s]
# 	Training Loss: 0.137626 	Validation Loss: 0.434752
# 	Train Accuracy: 95.183d% (38073/40000)	Valdation Accuracy: 87.590d% (8759/10000)
# train epoch[15/50]: 100%|██████████| 313/313 [00:16<00:00, 18.83it/s]
# valid epoch[15/50]: 100%|██████████| 79/79 [00:02<00:00, 33.60it/s]
# 	Training Loss: 0.132467 	Validation Loss: 0.551856
# 	Train Accuracy: 95.485d% (38194/40000)	Valdation Accuracy: 85.470d% (8547/10000)
# train epoch[16/50]: 100%|██████████| 313/313 [00:16<00:00, 18.84it/s]
# valid epoch[16/50]: 100%|██████████| 79/79 [00:02<00:00, 34.07it/s]
# 	Training Loss: 0.460167 	Validation Loss: 0.505282
# 	Train Accuracy: 86.112d% (34445/40000)	Valdation Accuracy: 83.260d% (8326/10000)
# train epoch[17/50]: 100%|██████████| 313/313 [00:16<00:00, 18.88it/s]
# valid epoch[17/50]: 100%|██████████| 79/79 [00:02<00:00, 33.96it/s]
# 	Training Loss: 0.212720 	Validation Loss: 0.406462
# 	Train Accuracy: 92.468d% (36987/40000)	Valdation Accuracy: 87.350d% (8735/10000)
# train epoch[18/50]: 100%|██████████| 313/313 [00:16<00:00, 18.87it/s]
# valid epoch[18/50]: 100%|██████████| 79/79 [00:02<00:00, 34.28it/s]
# 	Training Loss: 0.139472 	Validation Loss: 0.406168
# 	Train Accuracy: 95.093d% (38037/40000)	Valdation Accuracy: 88.380d% (8838/10000)
# train epoch[19/50]: 100%|██████████| 313/313 [00:16<00:00, 18.90it/s]
# valid epoch[19/50]: 100%|██████████| 79/79 [00:02<00:00, 34.49it/s]
# 	Training Loss: 0.122630 	Validation Loss: 0.425920
# 	Train Accuracy: 95.672d% (38269/40000)	Valdation Accuracy: 87.720d% (8772/10000)
# train epoch[20/50]: 100%|██████████| 313/313 [00:16<00:00, 18.87it/s]
# valid epoch[20/50]: 100%|██████████| 79/79 [00:02<00:00, 34.19it/s]
# 	Training Loss: 0.114571 	Validation Loss: 0.406926
# 	Train Accuracy: 95.983d% (38393/40000)	Valdation Accuracy: 88.140d% (8814/10000)
# train epoch[21/50]: 100%|██████████| 313/313 [00:16<00:00, 18.84it/s]
# valid epoch[21/50]: 100%|██████████| 79/79 [00:02<00:00, 34.28it/s]
# 	Training Loss: 0.108182 	Validation Loss: 0.413430
# 	Train Accuracy: 96.160d% (38464/40000)	Valdation Accuracy: 88.450d% (8845/10000)
# train epoch[22/50]: 100%|██████████| 313/313 [00:16<00:00, 18.84it/s]
# valid epoch[22/50]: 100%|██████████| 79/79 [00:02<00:00, 34.35it/s]
# 	Training Loss: 0.104618 	Validation Loss: 0.437004
# 	Train Accuracy: 96.250d% (38500/40000)	Valdation Accuracy: 88.310d% (8831/10000)
# train epoch[23/50]: 100%|██████████| 313/313 [00:16<00:00, 18.91it/s]
# valid epoch[23/50]: 100%|██████████| 79/79 [00:02<00:00, 34.15it/s]
# 	Training Loss: 0.100480 	Validation Loss: 0.448489
# 	Train Accuracy: 96.382d% (38553/40000)	Valdation Accuracy: 87.690d% (8769/10000)
# train epoch[24/50]: 100%|██████████| 313/313 [00:16<00:00, 18.91it/s]
# valid epoch[24/50]: 100%|██████████| 79/79 [00:02<00:00, 34.17it/s]
# 	Training Loss: 0.100728 	Validation Loss: 0.438486
# 	Train Accuracy: 96.400d% (38560/40000)	Valdation Accuracy: 88.310d% (8831/10000)
# train epoch[25/50]: 100%|██████████| 313/313 [00:16<00:00, 18.92it/s]
# valid epoch[25/50]: 100%|██████████| 79/79 [00:02<00:00, 34.05it/s]
# 	Training Loss: 0.095488 	Validation Loss: 0.467219
# 	Train Accuracy: 96.593d% (38637/40000)	Valdation Accuracy: 87.190d% (8719/10000)
# train epoch[26/50]: 100%|██████████| 313/313 [00:16<00:00, 18.90it/s]
# valid epoch[26/50]: 100%|██████████| 79/79 [00:02<00:00, 34.08it/s]
# 	Training Loss: 0.101906 	Validation Loss: 0.431564
# 	Train Accuracy: 96.422d% (38569/40000)	Valdation Accuracy: 88.010d% (8801/10000)
# train epoch[27/50]: 100%|██████████| 313/313 [00:16<00:00, 18.83it/s]
# valid epoch[27/50]: 100%|██████████| 79/79 [00:02<00:00, 34.27it/s]
# 	Training Loss: 0.095411 	Validation Loss: 0.442953
# 	Train Accuracy: 96.655d% (38662/40000)	Valdation Accuracy: 87.980d% (8798/10000)
# train epoch[28/50]: 100%|██████████| 313/313 [00:16<00:00, 18.86it/s]
# valid epoch[28/50]: 100%|██████████| 79/79 [00:02<00:00, 34.07it/s]
# 	Training Loss: 0.094711 	Validation Loss: 0.434260
# 	Train Accuracy: 96.748d% (38699/40000)	Valdation Accuracy: 88.400d% (8840/10000)
# train epoch[29/50]: 100%|██████████| 313/313 [00:16<00:00, 18.90it/s]
# valid epoch[29/50]: 100%|██████████| 79/79 [00:02<00:00, 34.06it/s]
# 	Training Loss: 0.089744 	Validation Loss: 0.487343
# 	Train Accuracy: 96.910d% (38764/40000)	Valdation Accuracy: 87.860d% (8786/10000)
# train epoch[30/50]: 100%|██████████| 313/313 [00:16<00:00, 18.82it/s]
# valid epoch[30/50]: 100%|██████████| 79/79 [00:02<00:00, 34.02it/s]
# 	Training Loss: 0.097471 	Validation Loss: 0.417311
# 	Train Accuracy: 96.625d% (38650/40000)	Valdation Accuracy: 88.530d% (8853/10000)
# train epoch[31/50]: 100%|██████████| 313/313 [00:16<00:00, 18.88it/s]
# valid epoch[31/50]: 100%|██████████| 79/79 [00:02<00:00, 33.86it/s]
# 	Training Loss: 0.090532 	Validation Loss: 0.451826
# 	Train Accuracy: 96.750d% (38700/40000)	Valdation Accuracy: 88.100d% (8810/10000)
# train epoch[32/50]: 100%|██████████| 313/313 [00:16<00:00, 18.83it/s]
# valid epoch[32/50]: 100%|██████████| 79/79 [00:02<00:00, 34.16it/s]
# 	Training Loss: 0.084034 	Validation Loss: 0.474404
# 	Train Accuracy: 97.073d% (38829/40000)	Valdation Accuracy: 88.290d% (8829/10000)
# train epoch[33/50]: 100%|██████████| 313/313 [00:16<00:00, 18.83it/s]
# valid epoch[33/50]: 100%|██████████| 79/79 [00:02<00:00, 33.87it/s]
# 	Training Loss: 0.086322 	Validation Loss: 0.489474
# 	Train Accuracy: 96.910d% (38764/40000)	Valdation Accuracy: 87.500d% (8750/10000)
# train epoch[34/50]: 100%|██████████| 313/313 [00:16<00:00, 18.78it/s]
# valid epoch[34/50]: 100%|██████████| 79/79 [00:02<00:00, 33.88it/s]
# 	Training Loss: 0.087538 	Validation Loss: 0.450469
# 	Train Accuracy: 96.918d% (38767/40000)	Valdation Accuracy: 88.170d% (8817/10000)
# train epoch[35/50]: 100%|██████████| 313/313 [00:16<00:00, 18.73it/s]
# valid epoch[35/50]: 100%|██████████| 79/79 [00:02<00:00, 34.27it/s]
# 	Training Loss: 0.079099 	Validation Loss: 0.470115
# 	Train Accuracy: 97.260d% (38904/40000)	Valdation Accuracy: 87.930d% (8793/10000)
# train epoch[36/50]: 100%|██████████| 313/313 [00:16<00:00, 18.87it/s]
# valid epoch[36/50]: 100%|██████████| 79/79 [00:02<00:00, 34.37it/s]
# 	Training Loss: 0.082632 	Validation Loss: 0.464678
# 	Train Accuracy: 97.132d% (38853/40000)	Valdation Accuracy: 88.290d% (8829/10000)
# train epoch[37/50]: 100%|██████████| 313/313 [00:16<00:00, 18.87it/s]
# valid epoch[37/50]: 100%|██████████| 79/79 [00:02<00:00, 34.33it/s]
# 	Training Loss: 0.073309 	Validation Loss: 0.505499
# 	Train Accuracy: 97.415d% (38966/40000)	Valdation Accuracy: 87.740d% (8774/10000)
# train epoch[38/50]: 100%|██████████| 313/313 [00:16<00:00, 18.88it/s]
# valid epoch[38/50]: 100%|██████████| 79/79 [00:02<00:00, 34.32it/s]
# 	Training Loss: 0.075709 	Validation Loss: 0.471147
# 	Train Accuracy: 97.445d% (38978/40000)	Valdation Accuracy: 87.990d% (8799/10000)
# train epoch[39/50]: 100%|██████████| 313/313 [00:16<00:00, 18.80it/s]
# valid epoch[39/50]: 100%|██████████| 79/79 [00:02<00:00, 31.87it/s]
# 	Training Loss: 0.070721 	Validation Loss: 0.453370
# 	Train Accuracy: 97.498d% (38999/40000)	Valdation Accuracy: 88.890d% (8889/10000)
# train epoch[40/50]: 100%|██████████| 313/313 [00:16<00:00, 18.75it/s]
# valid epoch[40/50]: 100%|██████████| 79/79 [00:02<00:00, 33.99it/s]
# 	Training Loss: 0.076866 	Validation Loss: 0.460567
# 	Train Accuracy: 97.275d% (38910/40000)	Valdation Accuracy: 88.480d% (8848/10000)
# train epoch[41/50]: 100%|██████████| 313/313 [00:16<00:00, 18.90it/s]
# valid epoch[41/50]: 100%|██████████| 79/79 [00:02<00:00, 34.07it/s]
# 	Training Loss: 0.071600 	Validation Loss: 0.448138
# 	Train Accuracy: 97.435d% (38974/40000)	Valdation Accuracy: 88.670d% (8867/10000)
# train epoch[42/50]: 100%|██████████| 313/313 [00:16<00:00, 18.90it/s]
# valid epoch[42/50]: 100%|██████████| 79/79 [00:02<00:00, 34.00it/s]
# 	Training Loss: 0.069358 	Validation Loss: 0.457479
# 	Train Accuracy: 97.567d% (39027/40000)	Valdation Accuracy: 88.250d% (8825/10000)
# train epoch[43/50]: 100%|██████████| 313/313 [00:16<00:00, 18.88it/s]
# valid epoch[43/50]: 100%|██████████| 79/79 [00:02<00:00, 34.35it/s]
# 	Training Loss: 0.068714 	Validation Loss: 0.491441
# 	Train Accuracy: 97.615d% (39046/40000)	Valdation Accuracy: 87.990d% (8799/10000)
# train epoch[44/50]: 100%|██████████| 313/313 [00:16<00:00, 18.89it/s]
# valid epoch[44/50]: 100%|██████████| 79/79 [00:02<00:00, 34.42it/s]
# 	Training Loss: 0.068927 	Validation Loss: 0.465054
# 	Train Accuracy: 97.608d% (39043/40000)	Valdation Accuracy: 88.580d% (8858/10000)
# train epoch[45/50]: 100%|██████████| 313/313 [00:16<00:00, 18.89it/s]
# valid epoch[45/50]: 100%|██████████| 79/79 [00:02<00:00, 34.10it/s]
# 	Training Loss: 0.067651 	Validation Loss: 0.453017
# 	Train Accuracy: 97.645d% (39058/40000)	Valdation Accuracy: 88.340d% (8834/10000)
# train epoch[46/50]: 100%|██████████| 313/313 [00:16<00:00, 18.83it/s]
# valid epoch[46/50]: 100%|██████████| 79/79 [00:02<00:00, 34.04it/s]
# 	Training Loss: 0.060160 	Validation Loss: 0.466456
# 	Train Accuracy: 97.935d% (39174/40000)	Valdation Accuracy: 88.460d% (8846/10000)
# train epoch[47/50]: 100%|██████████| 313/313 [00:16<00:00, 18.91it/s]
# valid epoch[47/50]: 100%|██████████| 79/79 [00:02<00:00, 34.17it/s]
# 	Training Loss: 0.062610 	Validation Loss: 0.499206
# 	Train Accuracy: 97.858d% (39143/40000)	Valdation Accuracy: 88.100d% (8810/10000)
# train epoch[48/50]: 100%|██████████| 313/313 [00:16<00:00, 18.85it/s]
# valid epoch[48/50]: 100%|██████████| 79/79 [00:02<00:00, 34.01it/s]
# 	Training Loss: 0.058740 	Validation Loss: 0.500705
# 	Train Accuracy: 97.935d% (39174/40000)	Valdation Accuracy: 88.630d% (8863/10000)
# train epoch[49/50]: 100%|██████████| 313/313 [00:16<00:00, 18.81it/s]
# valid epoch[49/50]: 100%|██████████| 79/79 [00:02<00:00, 34.05it/s]
# 	Training Loss: 0.061374 	Validation Loss: 0.471531
# 	Train Accuracy: 97.897d% (39159/40000)	Valdation Accuracy: 88.600d% (8860/10000)
# train epoch[50/50]: 100%|██████████| 313/313 [00:16<00:00, 18.84it/s]
# valid epoch[50/50]: 100%|██████████| 79/79 [00:02<00:00, 34.08it/s]
# 	Training Loss: 0.057969 	Validation Loss: 0.465258
# 	Train Accuracy: 98.032d% (39213/40000)	Valdation Accuracy: 89.320d% (8932/10000)
# Teacher.pt is saved
# Finished Training

# %%
T_loss, T_accuracy = test(Teacher, test_loader, device=device)
# Out:
# test: 100%|██████████| 79/79 [00:01<00:00, 40.15it/s]
# test_loss: 0.459  test_accuracy: 89.840

# %%
# Decide the epochs and learning rate
train_from_scratch(Student, train_loader, val_loader, epochs= 50 , learning_rate= 1e-3 , device=device, model_name="Student")
# Out:
# train epoch[1/50]: 100%|██████████| 313/313 [00:10<00:00, 30.03it/s]
# valid epoch[1/50]: 100%|██████████| 79/79 [00:01<00:00, 43.86it/s]
# 	Training Loss: 1.409035 	Validation Loss: 1.123096
# 	Train Accuracy: 48.617d% (19447/40000)	Valdation Accuracy: 59.640d% (5964/10000)
# train epoch[2/50]: 100%|██████████| 313/313 [00:09<00:00, 31.70it/s]
# valid epoch[2/50]: 100%|██████████| 79/79 [00:01<00:00, 43.13it/s]
# 	Training Loss: 1.011369 	Validation Loss: 1.268687
# 	Train Accuracy: 64.097d% (25639/40000)	Valdation Accuracy: 57.980d% (5798/10000)
# train epoch[3/50]: 100%|██████████| 313/313 [00:09<00:00, 31.68it/s]
# valid epoch[3/50]: 100%|██████████| 79/79 [00:01<00:00, 43.52it/s]
# 	Training Loss: 0.823543 	Validation Loss: 0.842080
# 	Train Accuracy: 71.118d% (28447/40000)	Valdation Accuracy: 70.590d% (7059/10000)
# train epoch[4/50]: 100%|██████████| 313/313 [00:09<00:00, 31.73it/s]
# valid epoch[4/50]: 100%|██████████| 79/79 [00:01<00:00, 43.47it/s]
# 	Training Loss: 0.715940 	Validation Loss: 0.752887
# 	Train Accuracy: 75.308d% (30123/40000)	Valdation Accuracy: 74.480d% (7448/10000)
# train epoch[5/50]: 100%|██████████| 313/313 [00:10<00:00, 31.14it/s]
# valid epoch[5/50]: 100%|██████████| 79/79 [00:01<00:00, 43.06it/s]
# 	Training Loss: 0.642766 	Validation Loss: 0.686452
# 	Train Accuracy: 77.562d% (31025/40000)	Valdation Accuracy: 76.320d% (7632/10000)
# train epoch[6/50]: 100%|██████████| 313/313 [00:09<00:00, 32.30it/s]
# valid epoch[6/50]: 100%|██████████| 79/79 [00:01<00:00, 45.54it/s]
# 	Training Loss: 0.584545 	Validation Loss: 0.684572
# 	Train Accuracy: 80.047d% (32019/40000)	Valdation Accuracy: 76.900d% (7690/10000)
# train epoch[7/50]: 100%|██████████| 313/313 [00:09<00:00, 32.13it/s]
# valid epoch[7/50]: 100%|██████████| 79/79 [00:01<00:00, 44.27it/s]
# 	Training Loss: 0.540193 	Validation Loss: 0.605889
# 	Train Accuracy: 81.293d% (32517/40000)	Valdation Accuracy: 79.690d% (7969/10000)
# train epoch[8/50]: 100%|██████████| 313/313 [00:09<00:00, 32.24it/s]
# valid epoch[8/50]: 100%|██████████| 79/79 [00:01<00:00, 44.28it/s]
# 	Training Loss: 0.499098 	Validation Loss: 0.704047
# 	Train Accuracy: 82.793d% (33117/40000)	Valdation Accuracy: 76.080d% (7608/10000)
# train epoch[9/50]: 100%|██████████| 313/313 [00:09<00:00, 32.41it/s]
# valid epoch[9/50]: 100%|██████████| 79/79 [00:01<00:00, 44.33it/s]
# 	Training Loss: 0.473495 	Validation Loss: 0.682253
# 	Train Accuracy: 83.683d% (33473/40000)	Valdation Accuracy: 77.280d% (7728/10000)
# train epoch[10/50]: 100%|██████████| 313/313 [00:09<00:00, 32.68it/s]
# valid epoch[10/50]: 100%|██████████| 79/79 [00:01<00:00, 45.60it/s]
# 	Training Loss: 0.438439 	Validation Loss: 0.603216
# 	Train Accuracy: 84.725d% (33890/40000)	Valdation Accuracy: 79.940d% (7994/10000)
# train epoch[11/50]: 100%|██████████| 313/313 [00:09<00:00, 32.19it/s]
# valid epoch[11/50]: 100%|██████████| 79/79 [00:01<00:00, 45.11it/s]
# 	Training Loss: 0.419726 	Validation Loss: 0.647513
# 	Train Accuracy: 85.552d% (34221/40000)	Valdation Accuracy: 78.400d% (7840/10000)
# train epoch[12/50]: 100%|██████████| 313/313 [00:09<00:00, 31.58it/s]
# valid epoch[12/50]: 100%|██████████| 79/79 [00:01<00:00, 44.81it/s]
# 	Training Loss: 0.390337 	Validation Loss: 0.502039
# 	Train Accuracy: 86.422d% (34569/40000)	Valdation Accuracy: 83.420d% (8342/10000)
# train epoch[13/50]: 100%|██████████| 313/313 [00:09<00:00, 31.48it/s]
# valid epoch[13/50]: 100%|██████████| 79/79 [00:01<00:00, 44.66it/s]
# 	Training Loss: 0.365897 	Validation Loss: 0.489494
# 	Train Accuracy: 87.177d% (34871/40000)	Valdation Accuracy: 83.430d% (8343/10000)
# train epoch[14/50]: 100%|██████████| 313/313 [00:09<00:00, 31.97it/s]
# valid epoch[14/50]: 100%|██████████| 79/79 [00:01<00:00, 44.34it/s]
# 	Training Loss: 0.353342 	Validation Loss: 0.497396
# 	Train Accuracy: 87.812d% (35125/40000)	Valdation Accuracy: 83.670d% (8367/10000)
# train epoch[15/50]: 100%|██████████| 313/313 [00:09<00:00, 32.28it/s]
# valid epoch[15/50]: 100%|██████████| 79/79 [00:01<00:00, 45.23it/s]
# 	Training Loss: 0.333809 	Validation Loss: 0.458905
# 	Train Accuracy: 88.323d% (35329/40000)	Valdation Accuracy: 84.720d% (8472/10000)
# train epoch[16/50]: 100%|██████████| 313/313 [00:09<00:00, 32.18it/s]
# valid epoch[16/50]: 100%|██████████| 79/79 [00:01<00:00, 44.34it/s]
# 	Training Loss: 0.316668 	Validation Loss: 0.517272
# 	Train Accuracy: 89.075d% (35630/40000)	Valdation Accuracy: 83.110d% (8311/10000)
# train epoch[17/50]: 100%|██████████| 313/313 [00:09<00:00, 32.40it/s]
# valid epoch[17/50]: 100%|██████████| 79/79 [00:01<00:00, 43.91it/s]
# 	Training Loss: 0.304318 	Validation Loss: 0.549091
# 	Train Accuracy: 89.540d% (35816/40000)	Valdation Accuracy: 82.980d% (8298/10000)
# train epoch[18/50]: 100%|██████████| 313/313 [00:09<00:00, 32.25it/s]
# valid epoch[18/50]: 100%|██████████| 79/79 [00:01<00:00, 44.20it/s]
# 	Training Loss: 0.287761 	Validation Loss: 0.493013
# 	Train Accuracy: 89.975d% (35990/40000)	Valdation Accuracy: 83.820d% (8382/10000)
# train epoch[19/50]: 100%|██████████| 313/313 [00:09<00:00, 32.53it/s]
# valid epoch[19/50]: 100%|██████████| 79/79 [00:01<00:00, 44.71it/s]
# 	Training Loss: 0.278093 	Validation Loss: 0.444614
# 	Train Accuracy: 90.287d% (36115/40000)	Valdation Accuracy: 85.380d% (8538/10000)
# train epoch[20/50]: 100%|██████████| 313/313 [00:09<00:00, 32.52it/s]
# valid epoch[20/50]: 100%|██████████| 79/79 [00:01<00:00, 45.21it/s]
# 	Training Loss: 0.262966 	Validation Loss: 0.481249
# 	Train Accuracy: 90.722d% (36289/40000)	Valdation Accuracy: 84.580d% (8458/10000)
# train epoch[21/50]: 100%|██████████| 313/313 [00:09<00:00, 32.62it/s]
# valid epoch[21/50]: 100%|██████████| 79/79 [00:01<00:00, 44.69it/s]
# 	Training Loss: 0.251443 	Validation Loss: 0.532021
# 	Train Accuracy: 91.185d% (36474/40000)	Valdation Accuracy: 83.480d% (8348/10000)
# train epoch[22/50]: 100%|██████████| 313/313 [00:09<00:00, 31.46it/s]
# valid epoch[22/50]: 100%|██████████| 79/79 [00:01<00:00, 45.25it/s]
# 	Training Loss: 0.235809 	Validation Loss: 0.441490
# 	Train Accuracy: 91.698d% (36679/40000)	Valdation Accuracy: 85.780d% (8578/10000)
# train epoch[23/50]: 100%|██████████| 313/313 [00:09<00:00, 31.31it/s]
# valid epoch[23/50]: 100%|██████████| 79/79 [00:01<00:00, 44.30it/s]
# 	Training Loss: 0.223751 	Validation Loss: 0.433730
# 	Train Accuracy: 92.385d% (36954/40000)	Valdation Accuracy: 86.040d% (8604/10000)
# train epoch[24/50]: 100%|██████████| 313/313 [00:09<00:00, 31.87it/s]
# valid epoch[24/50]: 100%|██████████| 79/79 [00:01<00:00, 45.22it/s]
# 	Training Loss: 0.216448 	Validation Loss: 0.454044
# 	Train Accuracy: 92.507d% (37003/40000)	Valdation Accuracy: 85.540d% (8554/10000)
# train epoch[25/50]: 100%|██████████| 313/313 [00:09<00:00, 32.35it/s]
# valid epoch[25/50]: 100%|██████████| 79/79 [00:01<00:00, 45.08it/s]
# 	Training Loss: 0.212820 	Validation Loss: 0.444498
# 	Train Accuracy: 92.412d% (36965/40000)	Valdation Accuracy: 86.470d% (8647/10000)
# train epoch[26/50]: 100%|██████████| 313/313 [00:09<00:00, 32.23it/s]
# valid epoch[26/50]: 100%|██████████| 79/79 [00:01<00:00, 45.37it/s]
# 	Training Loss: 0.198272 	Validation Loss: 0.474123
# 	Train Accuracy: 92.965d% (37186/40000)	Valdation Accuracy: 85.860d% (8586/10000)
# train epoch[27/50]: 100%|██████████| 313/313 [00:09<00:00, 31.70it/s]
# valid epoch[27/50]: 100%|██████████| 79/79 [00:01<00:00, 44.50it/s]
# 	Training Loss: 0.190768 	Validation Loss: 0.520458
# 	Train Accuracy: 93.295d% (37318/40000)	Valdation Accuracy: 84.760d% (8476/10000)
# train epoch[28/50]: 100%|██████████| 313/313 [00:09<00:00, 31.60it/s]
# valid epoch[28/50]: 100%|██████████| 79/79 [00:01<00:00, 43.31it/s]
# 	Training Loss: 0.187112 	Validation Loss: 0.470607
# 	Train Accuracy: 93.285d% (37314/40000)	Valdation Accuracy: 85.710d% (8571/10000)
# train epoch[29/50]: 100%|██████████| 313/313 [00:09<00:00, 31.92it/s]
# valid epoch[29/50]: 100%|██████████| 79/79 [00:01<00:00, 44.94it/s]
# 	Training Loss: 0.180098 	Validation Loss: 0.456541
# 	Train Accuracy: 93.715d% (37486/40000)	Valdation Accuracy: 86.060d% (8606/10000)
# train epoch[30/50]: 100%|██████████| 313/313 [00:09<00:00, 32.40it/s]
# valid epoch[30/50]: 100%|██████████| 79/79 [00:01<00:00, 44.25it/s]
# 	Training Loss: 0.167228 	Validation Loss: 0.473642
# 	Train Accuracy: 94.140d% (37656/40000)	Valdation Accuracy: 86.160d% (8616/10000)
# train epoch[31/50]: 100%|██████████| 313/313 [00:09<00:00, 32.23it/s]
# valid epoch[31/50]: 100%|██████████| 79/79 [00:01<00:00, 44.44it/s]
# 	Training Loss: 0.164395 	Validation Loss: 0.464028
# 	Train Accuracy: 94.175d% (37670/40000)	Valdation Accuracy: 86.230d% (8623/10000)
# train epoch[32/50]: 100%|██████████| 313/313 [00:09<00:00, 31.80it/s]
# valid epoch[32/50]: 100%|██████████| 79/79 [00:01<00:00, 43.13it/s]
# 	Training Loss: 0.158206 	Validation Loss: 0.474747
# 	Train Accuracy: 94.433d% (37773/40000)	Valdation Accuracy: 86.320d% (8632/10000)
# train epoch[33/50]: 100%|██████████| 313/313 [00:09<00:00, 31.61it/s]
# valid epoch[33/50]: 100%|██████████| 79/79 [00:01<00:00, 42.99it/s]
# 	Training Loss: 0.148690 	Validation Loss: 0.507227
# 	Train Accuracy: 94.718d% (37887/40000)	Valdation Accuracy: 85.380d% (8538/10000)
# train epoch[34/50]: 100%|██████████| 313/313 [00:09<00:00, 31.59it/s]
# valid epoch[34/50]: 100%|██████████| 79/79 [00:01<00:00, 44.85it/s]
# 	Training Loss: 0.148562 	Validation Loss: 0.485273
# 	Train Accuracy: 94.703d% (37881/40000)	Valdation Accuracy: 85.730d% (8573/10000)
# train epoch[35/50]: 100%|██████████| 313/313 [00:10<00:00, 31.29it/s]
# valid epoch[35/50]: 100%|██████████| 79/79 [00:01<00:00, 44.89it/s]
# 	Training Loss: 0.139397 	Validation Loss: 0.485869
# 	Train Accuracy: 95.135d% (38054/40000)	Valdation Accuracy: 86.650d% (8665/10000)
# train epoch[36/50]: 100%|██████████| 313/313 [00:10<00:00, 31.18it/s]
# valid epoch[36/50]: 100%|██████████| 79/79 [00:01<00:00, 44.28it/s]
# 	Training Loss: 0.139412 	Validation Loss: 0.479236
# 	Train Accuracy: 95.115d% (38046/40000)	Valdation Accuracy: 86.570d% (8657/10000)
# train epoch[37/50]: 100%|██████████| 313/313 [00:09<00:00, 31.56it/s]
# valid epoch[37/50]: 100%|██████████| 79/79 [00:01<00:00, 44.80it/s]
# 	Training Loss: 0.129178 	Validation Loss: 0.481693
# 	Train Accuracy: 95.407d% (38163/40000)	Valdation Accuracy: 86.310d% (8631/10000)
# train epoch[38/50]: 100%|██████████| 313/313 [00:09<00:00, 32.57it/s]
# valid epoch[38/50]: 100%|██████████| 79/79 [00:01<00:00, 43.89it/s]
# 	Training Loss: 0.130493 	Validation Loss: 0.465194
# 	Train Accuracy: 95.407d% (38163/40000)	Valdation Accuracy: 87.100d% (8710/10000)
# train epoch[39/50]: 100%|██████████| 313/313 [00:09<00:00, 32.19it/s]
# valid epoch[39/50]: 100%|██████████| 79/79 [00:01<00:00, 44.25it/s]
# 	Training Loss: 0.117754 	Validation Loss: 0.471626
# 	Train Accuracy: 95.823d% (38329/40000)	Valdation Accuracy: 87.140d% (8714/10000)
# train epoch[40/50]: 100%|██████████| 313/313 [00:09<00:00, 32.69it/s]
# valid epoch[40/50]: 100%|██████████| 79/79 [00:01<00:00, 45.59it/s]
# 	Training Loss: 0.119921 	Validation Loss: 0.497802
# 	Train Accuracy: 95.748d% (38299/40000)	Valdation Accuracy: 86.430d% (8643/10000)
# train epoch[41/50]: 100%|██████████| 313/313 [00:09<00:00, 32.46it/s]
# valid epoch[41/50]: 100%|██████████| 79/79 [00:01<00:00, 45.47it/s]
# 	Training Loss: 0.113590 	Validation Loss: 0.538416
# 	Train Accuracy: 95.978d% (38391/40000)	Valdation Accuracy: 85.790d% (8579/10000)
# train epoch[42/50]: 100%|██████████| 313/313 [00:09<00:00, 32.45it/s]
# valid epoch[42/50]: 100%|██████████| 79/79 [00:01<00:00, 44.10it/s]
# 	Training Loss: 0.108262 	Validation Loss: 0.536781
# 	Train Accuracy: 96.103d% (38441/40000)	Valdation Accuracy: 85.900d% (8590/10000)
# train epoch[43/50]: 100%|██████████| 313/313 [00:09<00:00, 31.75it/s]
# valid epoch[43/50]: 100%|██████████| 79/79 [00:01<00:00, 43.91it/s]
# 	Training Loss: 0.106821 	Validation Loss: 0.532024
# 	Train Accuracy: 96.172d% (38469/40000)	Valdation Accuracy: 85.770d% (8577/10000)
# train epoch[44/50]: 100%|██████████| 313/313 [00:10<00:00, 31.24it/s]
# valid epoch[44/50]: 100%|██████████| 79/79 [00:01<00:00, 43.98it/s]
# 	Training Loss: 0.106171 	Validation Loss: 0.480029
# 	Train Accuracy: 96.228d% (38491/40000)	Valdation Accuracy: 87.510d% (8751/10000)
# train epoch[45/50]: 100%|██████████| 313/313 [00:09<00:00, 32.11it/s]
# valid epoch[45/50]: 100%|██████████| 79/79 [00:01<00:00, 44.06it/s]
# 	Training Loss: 0.101398 	Validation Loss: 0.494666
# 	Train Accuracy: 96.385d% (38554/40000)	Valdation Accuracy: 87.160d% (8716/10000)
# train epoch[46/50]: 100%|██████████| 313/313 [00:09<00:00, 32.41it/s]
# valid epoch[46/50]: 100%|██████████| 79/79 [00:01<00:00, 43.63it/s]
# 	Training Loss: 0.100842 	Validation Loss: 0.487458
# 	Train Accuracy: 96.390d% (38556/40000)	Valdation Accuracy: 87.360d% (8736/10000)
# train epoch[47/50]: 100%|██████████| 313/313 [00:09<00:00, 31.90it/s]
# valid epoch[47/50]: 100%|██████████| 79/79 [00:01<00:00, 44.15it/s]
# 	Training Loss: 0.094345 	Validation Loss: 0.480434
# 	Train Accuracy: 96.638d% (38655/40000)	Valdation Accuracy: 87.460d% (8746/10000)
# train epoch[48/50]: 100%|██████████| 313/313 [00:09<00:00, 32.31it/s]
# valid epoch[48/50]: 100%|██████████| 79/79 [00:01<00:00, 45.06it/s]
# 	Training Loss: 0.095265 	Validation Loss: 0.514148
# 	Train Accuracy: 96.623d% (38649/40000)	Valdation Accuracy: 86.400d% (8640/10000)
# train epoch[49/50]: 100%|██████████| 313/313 [00:09<00:00, 31.97it/s]
# valid epoch[49/50]: 100%|██████████| 79/79 [00:01<00:00, 45.10it/s]
# 	Training Loss: 0.092609 	Validation Loss: 0.492743
# 	Train Accuracy: 96.715d% (38686/40000)	Valdation Accuracy: 87.490d% (8749/10000)
# train epoch[50/50]: 100%|██████████| 313/313 [00:09<00:00, 32.46it/s]
# valid epoch[50/50]: 100%|██████████| 79/79 [00:01<00:00, 45.65it/s]
# 	Training Loss: 0.085102 	Validation Loss: 0.519448
# 	Train Accuracy: 96.980d% (38792/40000)	Valdation Accuracy: 87.110d% (8711/10000)
# Student.pt is saved
# Finished Training

# %%
S_loss, S_accuracy = test(Student, test_loader, device=device)
# Out:
# test: 100%|██████████| 79/79 [00:01<00:00, 50.80it/s]
# test_loss: 0.514  test_accuracy: 87.500

# %% [markdown]
# ## Define distillation
#
# ### Define the loss functions

# %%
# Finish the loss function for response-based distillation.
def loss_re(student_logits, teacher_logits, target, temperature=5.0, alpha=0.9):
    # ---------------------------------------------------------
    # T (Temperature): 控制機率分佈的平滑程度。T 越高，分佈越平滑 (Dark Knowledge 越明顯)。
    # alpha: 平衡 Distillation Loss (學老師) 和 CE Loss (學正確答案) 的權重。
    # ---------------------------------------------------------

    T = temperature
    loss_student = nn.functional.cross_entropy(student_logits, target)

    distillation_loss = nn.functional.kl_div(
        nn.functional.log_softmax(student_logits / T, dim=1),
        nn.functional.softmax(teacher_logits / T, dim=1),
        reduction='batchmean'
    )


    total_loss = (1. - alpha) * loss_student + alpha * (T ** 2) * distillation_loss

    return total_loss

# %%
def loss_fe(student_features, teacher_features, student_logits, target, alpha=0.5):

    # 1. 計算原本的分類損失 (Cross Entropy)
    # 這是為了讓學生不要為了模仿特徵而忘記怎麼做分類
    loss_ce = nn.functional.cross_entropy(student_logits, target)

    # 2. 計算特徵蒸餾損失 (Feature Distillation Loss)
    # 使用 MSE (均方誤差) 來計算兩組特徵圖的差異
    loss_feat = 0

    # 我們遍歷每一層 (feature1 ~ feature4) 加總誤差
    # 注意：這裡假設傳進來的 student_features 已經經過「維度對齊」了！
    for s_feat, t_feat in zip(student_features, teacher_features):
        loss_feat += nn.functional.mse_loss(s_feat, t_feat)

    # 3. 結合兩者
    total_loss = (1. - alpha) * loss_ce + alpha * loss_feat

    return total_loss

# %% [markdown]
# ### Define Distillation Framework

# %%
class Distiller(nn.Module):
    def __init__(self, teacher, student, type):
        super(Distiller, self).__init__()
        self.teacher = teacher
        self.student = student
        self.type = type

        # ----------------------------------------------------------------
        # 1. Feature-Based KD 的維度對齊 (Connectors)
        # ----------------------------------------------------------------
        # 如果是 feature-based，我們需要建立 connector 來轉換維度
        # ResNet18 features channels: [64, 128, 256, 512]
        # ResNet50 features channels: [256, 512, 1024, 2048]
        # 我們用 1x1 Conv (kernel_size=1) 進行升維

        if self.type == 'feature':
            self.connectors = nn.ModuleList([
                nn.Conv2d(64, 256, kernel_size=1),   # feat1: 64 -> 256
                nn.Conv2d(128, 512, kernel_size=1),  # feat2: 128 -> 512
                nn.Conv2d(256, 1024, kernel_size=1), # feat3: 256 -> 1024
                nn.Conv2d(512, 2048, kernel_size=1)  # feat4: 512 -> 2048
            ])

        for param in self.teacher.parameters():
            param.requires_grad = False

    def forward(self, x, target):
        # ----------------------------------------------------------------
        # 2. Forward Pass
        # ----------------------------------------------------------------

        # 取得 Student 的 logits 和 features
        student_logits, student_features = self.student(x)

        # 取得 Teacher 的 logits 和 features (不需要計算梯度)
        with torch.no_grad():
            teacher_logits, teacher_features = self.teacher(x)

        # ----------------------------------------------------------------
        # 3. 計算 Loss
        # ----------------------------------------------------------------
        if self.type == 'response':
            # 呼叫之前寫好的 loss_re
            # 參數順序要對: (student_logits, teacher_logits, target)
            loss_distill = loss_re(student_logits, teacher_logits, target)

        elif self.type == 'feature':
            # 先將 Student 的 features 通過 Connector 升維
            s_features_transformed = []
            for i, connector in enumerate(self.connectors):
                s_features_transformed.append(connector(student_features[i]))

            loss_distill = loss_fe(s_features_transformed, teacher_features, student_logits, target)

        else:
            raise ValueError(f'Error: only support response-based and feature-based distillation')

        return student_logits, loss_distill

# %% [markdown]
# ### Training function

# %%
def train_distillation(distiller, student, train_loader, val_loader, epochs, learning_rate, device):
    ce_loss = nn.CrossEntropyLoss()
    # define the parameter the optimizer used
    optimizer = torch.optim.AdamW(filter(lambda p: p.requires_grad, distiller.parameters()), lr=learning_rate, weight_decay=1e-4)

    loss = []
    train_error=[]
    val_error = []
    valdation_error = []
    train_loss = []
    valdation_loss = []
    train_accuraacy = []
    valdation_accuracy= []

    for epoch in range(epochs):
        distiller.train()
        distiller.teacher.train()
        distiller.student.train()

        train_loss = 0.0
        valid_loss = 0.0
        train_acc = 0.0
        valid_acc  = 0.0
        correct = 0.
        total = 0.
        V_correct = 0.
        V_total = 0.
        train_bar = tqdm(train_loader, file=sys.stdout)
        for step, data in enumerate(train_bar):
            images, labels = data
            images, labels = images.to(device), labels.to(device)

            outputs, loss = distiller(images, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)
            pred = outputs.data.max(1, keepdim=True)[1]
            result = pred.eq(labels.data.view_as(pred))
            result = np.squeeze(result.cpu().numpy())
            correct += np.sum(result)
            total += images.size(0)
            train_bar.desc = "train epoch[{}/{}]".format(epoch + 1, epochs)

        distiller.eval()
        distiller.teacher.eval()
        distiller.student.eval()

        with torch.no_grad():
            val_bar = tqdm(val_loader, file=sys.stdout)
            for val_data in val_bar:

                val_images, val_labels = val_data
                val_images, val_labels = val_images.to(device), val_labels.to(device)

                outputs, loss = distiller(val_images, val_labels)

                valid_loss += loss.item() * val_images.size(0)
                pred = outputs.max(1, keepdim=True)[1]
                V_correct += np.sum(np.squeeze(pred.eq(val_labels.data.view_as(pred))).cpu().numpy())
                V_total += val_images.size(0)
                val_bar.desc = "valid epoch[{}/{}]".format(epoch + 1, epochs)

        train_loss = train_loss / len(train_loader.dataset)
        train_error.append(train_loss)
        valid_loss = valid_loss / len(val_loader.dataset)
        val_error.append(valid_loss)
        train_accuraacy.append( correct / total)
        valdation_accuracy.append(V_correct / V_total)

        print('\tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(train_loss, valid_loss))
        print('\tTrain Accuracy: %.3fd%% (%2d/%2d)\tValdation Accuracy: %.3fd%% (%2d/%2d) '% (100. * correct / total, correct, total, 100. * V_correct / V_total, V_correct, V_total))

    print('Finished Distilling')

# %% [markdown]
# ## Response-based distillation

# %%
# Decide the epochs and learning rate
Student_re = resnet18(num_classes=10)
Student_re = Student_re.to(device)
distiller_re = Distiller(Teacher, Student_re, type='response')
train_distillation(distiller_re, Student_re, train_loader, val_loader, epochs= 50  , learning_rate= 1e-3 , device=device)
# Out:
# train epoch[1/50]: 100%|██████████| 313/313 [00:12<00:00, 24.12it/s]
# valid epoch[1/50]: 100%|██████████| 79/79 [00:02<00:00, 30.45it/s]
# 	Training Loss: 13.766044 	Validation Loss: 11.934295
# 	Train Accuracy: 51.030d% (20412/40000)	Valdation Accuracy: 55.710d% (5571/10000)
# train epoch[2/50]: 100%|██████████| 313/313 [00:12<00:00, 24.88it/s]
# valid epoch[2/50]: 100%|██████████| 79/79 [00:02<00:00, 30.74it/s]
# 	Training Loss: 8.084339 	Validation Loss: 6.595953
# 	Train Accuracy: 67.528d% (27011/40000)	Valdation Accuracy: 70.180d% (7018/10000)
# train epoch[3/50]: 100%|██████████| 313/313 [00:12<00:00, 25.20it/s]
# valid epoch[3/50]: 100%|██████████| 79/79 [00:02<00:00, 30.00it/s]
# 	Training Loss: 5.815515 	Validation Loss: 6.399501
# 	Train Accuracy: 74.483d% (29793/40000)	Valdation Accuracy: 70.750d% (7075/10000)
# train epoch[4/50]: 100%|██████████| 313/313 [00:12<00:00, 24.97it/s]
# valid epoch[4/50]: 100%|██████████| 79/79 [00:02<00:00, 31.05it/s]
# 	Training Loss: 4.726374 	Validation Loss: 3.981583
# 	Train Accuracy: 77.987d% (31195/40000)	Valdation Accuracy: 77.980d% (7798/10000)
# train epoch[5/50]: 100%|██████████| 313/313 [00:12<00:00, 24.94it/s]
# valid epoch[5/50]: 100%|██████████| 79/79 [00:02<00:00, 30.72it/s]
# 	Training Loss: 4.031688 	Validation Loss: 3.946205
# 	Train Accuracy: 80.733d% (32293/40000)	Valdation Accuracy: 78.050d% (7805/10000)
# train epoch[6/50]: 100%|██████████| 313/313 [00:12<00:00, 25.11it/s]
# valid epoch[6/50]: 100%|██████████| 79/79 [00:02<00:00, 30.85it/s]
# 	Training Loss: 3.553559 	Validation Loss: 3.389534
# 	Train Accuracy: 82.373d% (32949/40000)	Valdation Accuracy: 80.310d% (8031/10000)
# train epoch[7/50]: 100%|██████████| 313/313 [00:12<00:00, 25.18it/s]
# valid epoch[7/50]: 100%|██████████| 79/79 [00:02<00:00, 31.17it/s]
# 	Training Loss: 3.193594 	Validation Loss: 4.157835
# 	Train Accuracy: 83.845d% (33538/40000)	Valdation Accuracy: 77.500d% (7750/10000)
# train epoch[8/50]: 100%|██████████| 313/313 [00:12<00:00, 25.06it/s]
# valid epoch[8/50]: 100%|██████████| 79/79 [00:02<00:00, 30.96it/s]
# 	Training Loss: 2.931084 	Validation Loss: 3.335771
# 	Train Accuracy: 84.638d% (33855/40000)	Valdation Accuracy: 80.420d% (8042/10000)
# train epoch[9/50]: 100%|██████████| 313/313 [00:12<00:00, 24.95it/s]
# valid epoch[9/50]: 100%|██████████| 79/79 [00:02<00:00, 30.70it/s]
# 	Training Loss: 2.645788 	Validation Loss: 2.926051
# 	Train Accuracy: 85.960d% (34384/40000)	Valdation Accuracy: 81.850d% (8185/10000)
# train epoch[10/50]: 100%|██████████| 313/313 [00:12<00:00, 24.94it/s]
# valid epoch[10/50]: 100%|██████████| 79/79 [00:02<00:00, 30.85it/s]
# 	Training Loss: 2.506923 	Validation Loss: 2.413112
# 	Train Accuracy: 86.510d% (34604/40000)	Valdation Accuracy: 83.750d% (8375/10000)
# train epoch[11/50]: 100%|██████████| 313/313 [00:12<00:00, 24.84it/s]
# valid epoch[11/50]: 100%|██████████| 79/79 [00:02<00:00, 30.80it/s]
# 	Training Loss: 2.340934 	Validation Loss: 2.254373
# 	Train Accuracy: 87.347d% (34939/40000)	Valdation Accuracy: 84.100d% (8410/10000)
# train epoch[12/50]: 100%|██████████| 313/313 [00:12<00:00, 25.00it/s]
# valid epoch[12/50]: 100%|██████████| 79/79 [00:02<00:00, 31.26it/s]
# 	Training Loss: 2.191709 	Validation Loss: 2.564947
# 	Train Accuracy: 88.035d% (35214/40000)	Valdation Accuracy: 83.710d% (8371/10000)
# train epoch[13/50]: 100%|██████████| 313/313 [00:12<00:00, 25.26it/s]
# valid epoch[13/50]: 100%|██████████| 79/79 [00:02<00:00, 31.20it/s]
# 	Training Loss: 2.032902 	Validation Loss: 2.299296
# 	Train Accuracy: 88.675d% (35470/40000)	Valdation Accuracy: 84.680d% (8468/10000)
# train epoch[14/50]: 100%|██████████| 313/313 [00:12<00:00, 25.20it/s]
# valid epoch[14/50]: 100%|██████████| 79/79 [00:02<00:00, 31.32it/s]
# 	Training Loss: 1.965888 	Validation Loss: 2.334801
# 	Train Accuracy: 89.132d% (35653/40000)	Valdation Accuracy: 84.080d% (8408/10000)
# train epoch[15/50]: 100%|██████████| 313/313 [00:12<00:00, 25.46it/s]
# valid epoch[15/50]: 100%|██████████| 79/79 [00:02<00:00, 31.08it/s]
# 	Training Loss: 1.857534 	Validation Loss: 2.344372
# 	Train Accuracy: 89.718d% (35887/40000)	Valdation Accuracy: 84.350d% (8435/10000)
# train epoch[16/50]: 100%|██████████| 313/313 [00:12<00:00, 25.10it/s]
# valid epoch[16/50]: 100%|██████████| 79/79 [00:02<00:00, 31.33it/s]
# 	Training Loss: 1.793114 	Validation Loss: 2.106880
# 	Train Accuracy: 90.030d% (36012/40000)	Valdation Accuracy: 85.770d% (8577/10000)
# train epoch[17/50]: 100%|██████████| 313/313 [00:12<00:00, 25.00it/s]
# valid epoch[17/50]: 100%|██████████| 79/79 [00:02<00:00, 31.17it/s]
# 	Training Loss: 1.732309 	Validation Loss: 2.261219
# 	Train Accuracy: 90.330d% (36132/40000)	Valdation Accuracy: 85.110d% (8511/10000)
# train epoch[18/50]: 100%|██████████| 313/313 [00:12<00:00, 25.05it/s]
# valid epoch[18/50]: 100%|██████████| 79/79 [00:02<00:00, 30.98it/s]
# 	Training Loss: 1.686996 	Validation Loss: 1.899562
# 	Train Accuracy: 90.640d% (36256/40000)	Valdation Accuracy: 85.910d% (8591/10000)
# train epoch[19/50]: 100%|██████████| 313/313 [00:12<00:00, 25.33it/s]
# valid epoch[19/50]: 100%|██████████| 79/79 [00:02<00:00, 30.10it/s]
# 	Training Loss: 1.598739 	Validation Loss: 1.931675
# 	Train Accuracy: 91.060d% (36424/40000)	Valdation Accuracy: 85.710d% (8571/10000)
# train epoch[20/50]: 100%|██████████| 313/313 [00:12<00:00, 25.27it/s]
# valid epoch[20/50]: 100%|██████████| 79/79 [00:02<00:00, 30.98it/s]
# 	Training Loss: 1.558518 	Validation Loss: 1.759855
# 	Train Accuracy: 91.172d% (36469/40000)	Valdation Accuracy: 86.370d% (8637/10000)
# train epoch[21/50]: 100%|██████████| 313/313 [00:12<00:00, 25.26it/s]
# valid epoch[21/50]: 100%|██████████| 79/79 [00:02<00:00, 30.82it/s]
# 	Training Loss: 1.485063 	Validation Loss: 1.754707
# 	Train Accuracy: 91.735d% (36694/40000)	Valdation Accuracy: 86.770d% (8677/10000)
# train epoch[22/50]: 100%|██████████| 313/313 [00:12<00:00, 25.35it/s]
# valid epoch[22/50]: 100%|██████████| 79/79 [00:02<00:00, 31.07it/s]
# 	Training Loss: 1.413836 	Validation Loss: 1.667162
# 	Train Accuracy: 92.005d% (36802/40000)	Valdation Accuracy: 86.540d% (8654/10000)
# train epoch[23/50]: 100%|██████████| 313/313 [00:12<00:00, 25.19it/s]
# valid epoch[23/50]: 100%|██████████| 79/79 [00:02<00:00, 31.28it/s]
# 	Training Loss: 1.396925 	Validation Loss: 1.750059
# 	Train Accuracy: 92.358d% (36943/40000)	Valdation Accuracy: 86.340d% (8634/10000)
# train epoch[24/50]: 100%|██████████| 313/313 [00:12<00:00, 25.11it/s]
# valid epoch[24/50]: 100%|██████████| 79/79 [00:02<00:00, 31.02it/s]
# 	Training Loss: 1.352161 	Validation Loss: 1.666303
# 	Train Accuracy: 92.672d% (37069/40000)	Valdation Accuracy: 87.290d% (8729/10000)
# train epoch[25/50]: 100%|██████████| 313/313 [00:12<00:00, 24.78it/s]
# valid epoch[25/50]: 100%|██████████| 79/79 [00:02<00:00, 30.78it/s]
# 	Training Loss: 1.286754 	Validation Loss: 1.844091
# 	Train Accuracy: 92.787d% (37115/40000)	Valdation Accuracy: 86.420d% (8642/10000)
# train epoch[26/50]: 100%|██████████| 313/313 [00:12<00:00, 25.06it/s]
# valid epoch[26/50]: 100%|██████████| 79/79 [00:02<00:00, 31.09it/s]
# 	Training Loss: 1.277719 	Validation Loss: 1.724991
# 	Train Accuracy: 92.957d% (37183/40000)	Valdation Accuracy: 86.560d% (8656/10000)
# train epoch[27/50]: 100%|██████████| 313/313 [00:12<00:00, 25.14it/s]
# valid epoch[27/50]: 100%|██████████| 79/79 [00:02<00:00, 30.19it/s]
# 	Training Loss: 1.277098 	Validation Loss: 1.630799
# 	Train Accuracy: 93.188d% (37275/40000)	Valdation Accuracy: 87.210d% (8721/10000)
# train epoch[28/50]: 100%|██████████| 313/313 [00:12<00:00, 24.82it/s]
# valid epoch[28/50]: 100%|██████████| 79/79 [00:02<00:00, 30.93it/s]
# 	Training Loss: 1.184802 	Validation Loss: 1.647567
# 	Train Accuracy: 93.505d% (37402/40000)	Valdation Accuracy: 87.040d% (8704/10000)
# train epoch[29/50]: 100%|██████████| 313/313 [00:12<00:00, 24.93it/s]
# valid epoch[29/50]: 100%|██████████| 79/79 [00:02<00:00, 30.91it/s]
# 	Training Loss: 1.186327 	Validation Loss: 1.575013
# 	Train Accuracy: 93.582d% (37433/40000)	Valdation Accuracy: 87.090d% (8709/10000)
# train epoch[30/50]: 100%|██████████| 313/313 [00:12<00:00, 25.15it/s]
# valid epoch[30/50]: 100%|██████████| 79/79 [00:02<00:00, 31.03it/s]
# 	Training Loss: 1.152129 	Validation Loss: 1.691170
# 	Train Accuracy: 93.662d% (37465/40000)	Valdation Accuracy: 86.520d% (8652/10000)
# train epoch[31/50]: 100%|██████████| 313/313 [00:12<00:00, 25.20it/s]
# valid epoch[31/50]: 100%|██████████| 79/79 [00:02<00:00, 31.04it/s]
# 	Training Loss: 1.117236 	Validation Loss: 1.564294
# 	Train Accuracy: 93.850d% (37540/40000)	Valdation Accuracy: 88.130d% (8813/10000)
# train epoch[32/50]: 100%|██████████| 313/313 [00:12<00:00, 25.06it/s]
# valid epoch[32/50]: 100%|██████████| 79/79 [00:02<00:00, 30.69it/s]
# 	Training Loss: 1.111361 	Validation Loss: 1.594204
# 	Train Accuracy: 94.015d% (37606/40000)	Valdation Accuracy: 87.310d% (8731/10000)
# train epoch[33/50]: 100%|██████████| 313/313 [00:12<00:00, 24.87it/s]
# valid epoch[33/50]: 100%|██████████| 79/79 [00:02<00:00, 30.82it/s]
# 	Training Loss: 1.072016 	Validation Loss: 1.589036
# 	Train Accuracy: 94.345d% (37738/40000)	Valdation Accuracy: 87.280d% (8728/10000)
# train epoch[34/50]: 100%|██████████| 313/313 [00:12<00:00, 24.95it/s]
# valid epoch[34/50]: 100%|██████████| 79/79 [00:02<00:00, 30.99it/s]
# 	Training Loss: 1.057001 	Validation Loss: 1.496393
# 	Train Accuracy: 94.412d% (37765/40000)	Valdation Accuracy: 87.410d% (8741/10000)
# train epoch[35/50]: 100%|██████████| 313/313 [00:12<00:00, 24.70it/s]
# valid epoch[35/50]: 100%|██████████| 79/79 [00:02<00:00, 30.69it/s]
# 	Training Loss: 1.031509 	Validation Loss: 1.517340
# 	Train Accuracy: 94.530d% (37812/40000)	Valdation Accuracy: 87.110d% (8711/10000)
# train epoch[36/50]: 100%|██████████| 313/313 [00:12<00:00, 25.12it/s]
# valid epoch[36/50]: 100%|██████████| 79/79 [00:02<00:00, 31.08it/s]
# 	Training Loss: 1.035244 	Validation Loss: 1.516662
# 	Train Accuracy: 94.575d% (37830/40000)	Valdation Accuracy: 87.270d% (8727/10000)
# train epoch[37/50]: 100%|██████████| 313/313 [00:12<00:00, 25.32it/s]
# valid epoch[37/50]: 100%|██████████| 79/79 [00:02<00:00, 31.29it/s]
# 	Training Loss: 1.016824 	Validation Loss: 1.456165
# 	Train Accuracy: 94.468d% (37787/40000)	Valdation Accuracy: 87.380d% (8738/10000)
# train epoch[38/50]: 100%|██████████| 313/313 [00:12<00:00, 25.40it/s]
# valid epoch[38/50]: 100%|██████████| 79/79 [00:02<00:00, 31.21it/s]
# 	Training Loss: 0.984252 	Validation Loss: 1.352323
# 	Train Accuracy: 94.882d% (37953/40000)	Valdation Accuracy: 87.870d% (8787/10000)
# train epoch[39/50]: 100%|██████████| 313/313 [00:12<00:00, 25.32it/s]
# valid epoch[39/50]: 100%|██████████| 79/79 [00:02<00:00, 31.13it/s]
# 	Training Loss: 0.982792 	Validation Loss: 1.441856
# 	Train Accuracy: 94.862d% (37945/40000)	Valdation Accuracy: 87.650d% (8765/10000)
# train epoch[40/50]: 100%|██████████| 313/313 [00:12<00:00, 25.13it/s]
# valid epoch[40/50]: 100%|██████████| 79/79 [00:02<00:00, 30.98it/s]
# 	Training Loss: 0.943616 	Validation Loss: 1.292399
# 	Train Accuracy: 95.025d% (38010/40000)	Valdation Accuracy: 88.750d% (8875/10000)
# train epoch[41/50]: 100%|██████████| 313/313 [00:12<00:00, 25.05it/s]
# valid epoch[41/50]: 100%|██████████| 79/79 [00:02<00:00, 30.71it/s]
# 	Training Loss: 0.924821 	Validation Loss: 1.337113
# 	Train Accuracy: 95.237d% (38095/40000)	Valdation Accuracy: 88.600d% (8860/10000)
# train epoch[42/50]: 100%|██████████| 313/313 [00:12<00:00, 25.19it/s]
# valid epoch[42/50]: 100%|██████████| 79/79 [00:02<00:00, 31.02it/s]
# 	Training Loss: 0.915043 	Validation Loss: 1.381798
# 	Train Accuracy: 95.162d% (38065/40000)	Valdation Accuracy: 88.600d% (8860/10000)
# train epoch[43/50]: 100%|██████████| 313/313 [00:12<00:00, 25.15it/s]
# valid epoch[43/50]: 100%|██████████| 79/79 [00:02<00:00, 31.20it/s]
# 	Training Loss: 0.912350 	Validation Loss: 1.359801
# 	Train Accuracy: 95.392d% (38157/40000)	Valdation Accuracy: 88.600d% (8860/10000)
# train epoch[44/50]: 100%|██████████| 313/313 [00:12<00:00, 25.19it/s]
# valid epoch[44/50]: 100%|██████████| 79/79 [00:02<00:00, 30.87it/s]
# 	Training Loss: 0.882773 	Validation Loss: 1.459119
# 	Train Accuracy: 95.453d% (38181/40000)	Valdation Accuracy: 87.830d% (8783/10000)
# train epoch[45/50]: 100%|██████████| 313/313 [00:12<00:00, 25.13it/s]
# valid epoch[45/50]: 100%|██████████| 79/79 [00:02<00:00, 31.17it/s]
# 	Training Loss: 0.869345 	Validation Loss: 1.281407
# 	Train Accuracy: 95.593d% (38237/40000)	Valdation Accuracy: 88.500d% (8850/10000)
# train epoch[46/50]: 100%|██████████| 313/313 [00:12<00:00, 25.32it/s]
# valid epoch[46/50]: 100%|██████████| 79/79 [00:02<00:00, 31.21it/s]
# 	Training Loss: 0.881302 	Validation Loss: 1.366250
# 	Train Accuracy: 95.695d% (38278/40000)	Valdation Accuracy: 88.060d% (8806/10000)
# train epoch[47/50]: 100%|██████████| 313/313 [00:12<00:00, 25.45it/s]
# valid epoch[47/50]: 100%|██████████| 79/79 [00:02<00:00, 30.95it/s]
# 	Training Loss: 0.861598 	Validation Loss: 1.299184
# 	Train Accuracy: 95.517d% (38207/40000)	Valdation Accuracy: 88.350d% (8835/10000)
# train epoch[48/50]: 100%|██████████| 313/313 [00:12<00:00, 25.12it/s]
# valid epoch[48/50]: 100%|██████████| 79/79 [00:02<00:00, 31.10it/s]
# 	Training Loss: 0.837676 	Validation Loss: 1.282644
# 	Train Accuracy: 95.903d% (38361/40000)	Valdation Accuracy: 88.950d% (8895/10000)
# train epoch[49/50]: 100%|██████████| 313/313 [00:12<00:00, 25.04it/s]
# valid epoch[49/50]: 100%|██████████| 79/79 [00:02<00:00, 30.99it/s]
# 	Training Loss: 0.829886 	Validation Loss: 1.315756
# 	Train Accuracy: 95.892d% (38357/40000)	Valdation Accuracy: 88.400d% (8840/10000)
# train epoch[50/50]: 100%|██████████| 313/313 [00:12<00:00, 25.08it/s]
# valid epoch[50/50]: 100%|██████████| 79/79 [00:02<00:00, 31.20it/s]
# 	Training Loss: 0.826650 	Validation Loss: 1.273700
# 	Train Accuracy: 95.942d% (38377/40000)	Valdation Accuracy: 88.730d% (8873/10000)
# Finished Distilling

# %%
reS_loss, reS_accuracy = test(distiller_re, test_loader, type='distiller', device=device)
# Out:
# test: 100%|██████████| 79/79 [00:02<00:00, 32.44it/s]
# test_loss: 1.360  test_accuracy: 89.460

# %% [markdown]
# ## Feature-based distillation

# %%
# Decide the epochs and learning rate
Student_fe = resnet18(num_classes=10)
Student_fe = Student_fe.to(device)
distiller_fe = Distiller(Teacher, Student_fe, type='feature')
distiller_fe = distiller_fe.to(device)
train_distillation(distiller_fe, Student_fe, train_loader, val_loader, epochs= 50 , learning_rate= 1e-3 , device=device)
# Out:
# train epoch[1/50]: 100%|██████████| 313/313 [00:14<00:00, 22.24it/s]
# valid epoch[1/50]: 100%|██████████| 79/79 [00:02<00:00, 28.79it/s]
# 	Training Loss: 3.196629 	Validation Loss: 2.681766
# 	Train Accuracy: 46.895d% (18758/40000)	Valdation Accuracy: 56.950d% (5695/10000)
# train epoch[2/50]: 100%|██████████| 313/313 [00:13<00:00, 22.39it/s]
# valid epoch[2/50]: 100%|██████████| 79/79 [00:02<00:00, 28.99it/s]
# 	Training Loss: 2.203169 	Validation Loss: 2.061657
# 	Train Accuracy: 65.540d% (26216/40000)	Valdation Accuracy: 69.820d% (6982/10000)
# train epoch[3/50]: 100%|██████████| 313/313 [00:13<00:00, 22.47it/s]
# valid epoch[3/50]: 100%|██████████| 79/79 [00:02<00:00, 28.80it/s]
# 	Training Loss: 1.853790 	Validation Loss: 2.004774
# 	Train Accuracy: 73.790d% (29516/40000)	Valdation Accuracy: 74.180d% (7418/10000)
# train epoch[4/50]: 100%|██████████| 313/313 [00:13<00:00, 22.37it/s]
# valid epoch[4/50]: 100%|██████████| 79/79 [00:02<00:00, 28.54it/s]
# 	Training Loss: 1.680830 	Validation Loss: 1.802797
# 	Train Accuracy: 77.722d% (31089/40000)	Valdation Accuracy: 76.110d% (7611/10000)
# train epoch[5/50]: 100%|██████████| 313/313 [00:14<00:00, 22.29it/s]
# valid epoch[5/50]: 100%|██████████| 79/79 [00:02<00:00, 28.70it/s]
# 	Training Loss: 1.558751 	Validation Loss: 1.718787
# 	Train Accuracy: 80.198d% (32079/40000)	Valdation Accuracy: 76.700d% (7670/10000)
# train epoch[6/50]: 100%|██████████| 313/313 [00:14<00:00, 22.32it/s]
# valid epoch[6/50]: 100%|██████████| 79/79 [00:02<00:00, 28.68it/s]
# 	Training Loss: 1.484775 	Validation Loss: 1.614274
# 	Train Accuracy: 82.080d% (32832/40000)	Valdation Accuracy: 78.590d% (7859/10000)
# train epoch[7/50]: 100%|██████████| 313/313 [00:13<00:00, 22.44it/s]
# valid epoch[7/50]: 100%|██████████| 79/79 [00:02<00:00, 28.73it/s]
# 	Training Loss: 1.411852 	Validation Loss: 1.500198
# 	Train Accuracy: 83.855d% (33542/40000)	Valdation Accuracy: 81.440d% (8144/10000)
# train epoch[8/50]: 100%|██████████| 313/313 [00:14<00:00, 22.33it/s]
# valid epoch[8/50]: 100%|██████████| 79/79 [00:02<00:00, 28.86it/s]
# 	Training Loss: 1.368257 	Validation Loss: 1.447314
# 	Train Accuracy: 85.080d% (34032/40000)	Valdation Accuracy: 82.010d% (8201/10000)
# train epoch[9/50]: 100%|██████████| 313/313 [00:13<00:00, 22.39it/s]
# valid epoch[9/50]: 100%|██████████| 79/79 [00:02<00:00, 28.77it/s]
# 	Training Loss: 1.311357 	Validation Loss: 1.405633
# 	Train Accuracy: 86.138d% (34455/40000)	Valdation Accuracy: 82.830d% (8283/10000)
# train epoch[10/50]: 100%|██████████| 313/313 [00:13<00:00, 22.47it/s]
# valid epoch[10/50]: 100%|██████████| 79/79 [00:02<00:00, 28.68it/s]
# 	Training Loss: 1.285045 	Validation Loss: 1.355802
# 	Train Accuracy: 86.832d% (34733/40000)	Valdation Accuracy: 84.240d% (8424/10000)
# train epoch[11/50]: 100%|██████████| 313/313 [00:14<00:00, 22.21it/s]
# valid epoch[11/50]: 100%|██████████| 79/79 [00:02<00:00, 28.38it/s]
# 	Training Loss: 1.260698 	Validation Loss: 1.410825
# 	Train Accuracy: 87.688d% (35075/40000)	Valdation Accuracy: 83.100d% (8310/10000)
# train epoch[12/50]: 100%|██████████| 313/313 [00:14<00:00, 22.08it/s]
# valid epoch[12/50]: 100%|██████████| 79/79 [00:02<00:00, 28.52it/s]
# 	Training Loss: 1.218932 	Validation Loss: 1.318722
# 	Train Accuracy: 88.642d% (35457/40000)	Valdation Accuracy: 84.370d% (8437/10000)
# train epoch[13/50]: 100%|██████████| 313/313 [00:13<00:00, 22.39it/s]
# valid epoch[13/50]: 100%|██████████| 79/79 [00:02<00:00, 28.62it/s]
# 	Training Loss: 1.198232 	Validation Loss: 1.275819
# 	Train Accuracy: 88.862d% (35545/40000)	Valdation Accuracy: 85.370d% (8537/10000)
# train epoch[14/50]: 100%|██████████| 313/313 [00:14<00:00, 22.34it/s]
# valid epoch[14/50]: 100%|██████████| 79/79 [00:02<00:00, 28.52it/s]
# 	Training Loss: 1.184158 	Validation Loss: 1.311090
# 	Train Accuracy: 89.407d% (35763/40000)	Valdation Accuracy: 84.900d% (8490/10000)
# train epoch[15/50]: 100%|██████████| 313/313 [00:14<00:00, 21.94it/s]
# valid epoch[15/50]: 100%|██████████| 79/79 [00:02<00:00, 28.18it/s]
# 	Training Loss: 1.159382 	Validation Loss: 1.268867
# 	Train Accuracy: 90.168d% (36067/40000)	Valdation Accuracy: 85.530d% (8553/10000)
# train epoch[16/50]: 100%|██████████| 313/313 [00:14<00:00, 22.20it/s]
# valid epoch[16/50]: 100%|██████████| 79/79 [00:02<00:00, 28.61it/s]
# 	Training Loss: 1.147286 	Validation Loss: 1.332824
# 	Train Accuracy: 90.665d% (36266/40000)	Valdation Accuracy: 84.930d% (8493/10000)
# train epoch[17/50]: 100%|██████████| 313/313 [00:14<00:00, 22.21it/s]
# valid epoch[17/50]: 100%|██████████| 79/79 [00:02<00:00, 28.46it/s]
# 	Training Loss: 1.121132 	Validation Loss: 1.336369
# 	Train Accuracy: 91.025d% (36410/40000)	Valdation Accuracy: 84.380d% (8438/10000)
# train epoch[18/50]: 100%|██████████| 313/313 [00:13<00:00, 22.43it/s]
# valid epoch[18/50]: 100%|██████████| 79/79 [00:02<00:00, 28.75it/s]
# 	Training Loss: 1.112530 	Validation Loss: 1.318032
# 	Train Accuracy: 91.427d% (36571/40000)	Valdation Accuracy: 86.220d% (8622/10000)
# train epoch[19/50]: 100%|██████████| 313/313 [00:13<00:00, 22.41it/s]
# valid epoch[19/50]: 100%|██████████| 79/79 [00:02<00:00, 28.61it/s]
# 	Training Loss: 1.100309 	Validation Loss: 1.283501
# 	Train Accuracy: 92.127d% (36851/40000)	Valdation Accuracy: 86.280d% (8628/10000)
# train epoch[20/50]: 100%|██████████| 313/313 [00:13<00:00, 22.40it/s]
# valid epoch[20/50]: 100%|██████████| 79/79 [00:02<00:00, 28.86it/s]
# 	Training Loss: 1.079630 	Validation Loss: 1.273769
# 	Train Accuracy: 92.317d% (36927/40000)	Valdation Accuracy: 84.960d% (8496/10000)
# train epoch[21/50]: 100%|██████████| 313/313 [00:14<00:00, 22.34it/s]
# valid epoch[21/50]: 100%|██████████| 79/79 [00:02<00:00, 28.75it/s]
# 	Training Loss: 1.067027 	Validation Loss: 1.234270
# 	Train Accuracy: 92.668d% (37067/40000)	Valdation Accuracy: 86.370d% (8637/10000)
# train epoch[22/50]: 100%|██████████| 313/313 [00:13<00:00, 22.46it/s]
# valid epoch[22/50]: 100%|██████████| 79/79 [00:02<00:00, 28.79it/s]
# 	Training Loss: 1.067886 	Validation Loss: 1.296715
# 	Train Accuracy: 92.825d% (37130/40000)	Valdation Accuracy: 85.640d% (8564/10000)
# train epoch[23/50]: 100%|██████████| 313/313 [00:13<00:00, 22.41it/s]
# valid epoch[23/50]: 100%|██████████| 79/79 [00:02<00:00, 28.83it/s]
# 	Training Loss: 1.052567 	Validation Loss: 1.199299
# 	Train Accuracy: 93.183d% (37273/40000)	Valdation Accuracy: 86.870d% (8687/10000)
# train epoch[24/50]: 100%|██████████| 313/313 [00:13<00:00, 22.40it/s]
# valid epoch[24/50]: 100%|██████████| 79/79 [00:02<00:00, 28.69it/s]
# 	Training Loss: 1.047102 	Validation Loss: 1.244109
# 	Train Accuracy: 93.390d% (37356/40000)	Valdation Accuracy: 85.470d% (8547/10000)
# train epoch[25/50]: 100%|██████████| 313/313 [00:13<00:00, 22.40it/s]
# valid epoch[25/50]: 100%|██████████| 79/79 [00:02<00:00, 28.71it/s]
# 	Training Loss: 1.033767 	Validation Loss: 1.209333
# 	Train Accuracy: 93.505d% (37402/40000)	Valdation Accuracy: 86.850d% (8685/10000)
# train epoch[26/50]: 100%|██████████| 313/313 [00:14<00:00, 22.26it/s]
# valid epoch[26/50]: 100%|██████████| 79/79 [00:02<00:00, 28.75it/s]
# 	Training Loss: 1.025585 	Validation Loss: 1.221043
# 	Train Accuracy: 94.085d% (37634/40000)	Valdation Accuracy: 86.920d% (8692/10000)
# train epoch[27/50]: 100%|██████████| 313/313 [00:13<00:00, 22.40it/s]
# valid epoch[27/50]: 100%|██████████| 79/79 [00:02<00:00, 28.52it/s]
# 	Training Loss: 1.014597 	Validation Loss: 1.181540
# 	Train Accuracy: 94.257d% (37703/40000)	Valdation Accuracy: 87.000d% (8700/10000)
# train epoch[28/50]: 100%|██████████| 313/313 [00:14<00:00, 22.35it/s]
# valid epoch[28/50]: 100%|██████████| 79/79 [00:02<00:00, 28.51it/s]
# 	Training Loss: 1.005307 	Validation Loss: 1.211703
# 	Train Accuracy: 94.418d% (37767/40000)	Valdation Accuracy: 86.590d% (8659/10000)
# train epoch[29/50]: 100%|██████████| 313/313 [00:13<00:00, 22.39it/s]
# valid epoch[29/50]: 100%|██████████| 79/79 [00:02<00:00, 28.37it/s]
# 	Training Loss: 1.005784 	Validation Loss: 1.162638
# 	Train Accuracy: 94.560d% (37824/40000)	Valdation Accuracy: 87.280d% (8728/10000)
# train epoch[30/50]: 100%|██████████| 313/313 [00:14<00:00, 22.25it/s]
# valid epoch[30/50]: 100%|██████████| 79/79 [00:02<00:00, 28.69it/s]
# 	Training Loss: 0.994409 	Validation Loss: 1.145630
# 	Train Accuracy: 94.862d% (37945/40000)	Valdation Accuracy: 87.270d% (8727/10000)
# train epoch[31/50]: 100%|██████████| 313/313 [00:13<00:00, 22.54it/s]
# valid epoch[31/50]: 100%|██████████| 79/79 [00:02<00:00, 28.76it/s]
# 	Training Loss: 1.000455 	Validation Loss: 1.170865
# 	Train Accuracy: 94.750d% (37900/40000)	Valdation Accuracy: 86.800d% (8680/10000)
# train epoch[32/50]: 100%|██████████| 313/313 [00:13<00:00, 22.39it/s]
# valid epoch[32/50]: 100%|██████████| 79/79 [00:02<00:00, 28.32it/s]
# 	Training Loss: 0.993630 	Validation Loss: 1.153308
# 	Train Accuracy: 94.905d% (37962/40000)	Valdation Accuracy: 87.640d% (8764/10000)
# train epoch[33/50]: 100%|██████████| 313/313 [00:14<00:00, 22.28it/s]
# valid epoch[33/50]: 100%|██████████| 79/79 [00:02<00:00, 28.49it/s]
# 	Training Loss: 0.980462 	Validation Loss: 1.203025
# 	Train Accuracy: 95.257d% (38103/40000)	Valdation Accuracy: 87.000d% (8700/10000)
# train epoch[34/50]: 100%|██████████| 313/313 [00:14<00:00, 22.22it/s]
# valid epoch[34/50]: 100%|██████████| 79/79 [00:02<00:00, 28.81it/s]
# 	Training Loss: 0.982588 	Validation Loss: 1.181641
# 	Train Accuracy: 95.255d% (38102/40000)	Valdation Accuracy: 87.210d% (8721/10000)
# train epoch[35/50]: 100%|██████████| 313/313 [00:14<00:00, 22.34it/s]
# valid epoch[35/50]: 100%|██████████| 79/79 [00:02<00:00, 28.66it/s]
# 	Training Loss: 0.966172 	Validation Loss: 1.139259
# 	Train Accuracy: 95.555d% (38222/40000)	Valdation Accuracy: 88.250d% (8825/10000)
# train epoch[36/50]: 100%|██████████| 313/313 [00:14<00:00, 22.13it/s]
# valid epoch[36/50]: 100%|██████████| 79/79 [00:02<00:00, 28.15it/s]
# 	Training Loss: 0.958840 	Validation Loss: 1.249319
# 	Train Accuracy: 95.642d% (38257/40000)	Valdation Accuracy: 87.010d% (8701/10000)
# train epoch[37/50]: 100%|██████████| 313/313 [00:14<00:00, 21.99it/s]
# valid epoch[37/50]: 100%|██████████| 79/79 [00:02<00:00, 28.50it/s]
# 	Training Loss: 0.956338 	Validation Loss: 1.121810
# 	Train Accuracy: 95.935d% (38374/40000)	Valdation Accuracy: 87.460d% (8746/10000)
# train epoch[38/50]: 100%|██████████| 313/313 [00:14<00:00, 22.35it/s]
# valid epoch[38/50]: 100%|██████████| 79/79 [00:02<00:00, 28.48it/s]
# 	Training Loss: 0.953467 	Validation Loss: 1.148028
# 	Train Accuracy: 96.030d% (38412/40000)	Valdation Accuracy: 87.680d% (8768/10000)
# train epoch[39/50]: 100%|██████████| 313/313 [00:13<00:00, 22.38it/s]
# valid epoch[39/50]: 100%|██████████| 79/79 [00:02<00:00, 28.78it/s]
# 	Training Loss: 0.952031 	Validation Loss: 1.156187
# 	Train Accuracy: 95.970d% (38388/40000)	Valdation Accuracy: 87.770d% (8777/10000)
# train epoch[40/50]: 100%|██████████| 313/313 [00:13<00:00, 22.42it/s]
# valid epoch[40/50]: 100%|██████████| 79/79 [00:02<00:00, 28.71it/s]
# 	Training Loss: 0.938156 	Validation Loss: 1.151160
# 	Train Accuracy: 96.335d% (38534/40000)	Valdation Accuracy: 88.270d% (8827/10000)
# train epoch[41/50]: 100%|██████████| 313/313 [00:13<00:00, 22.41it/s]
# valid epoch[41/50]: 100%|██████████| 79/79 [00:02<00:00, 28.78it/s]
# 	Training Loss: 0.949046 	Validation Loss: 1.136034
# 	Train Accuracy: 96.153d% (38461/40000)	Valdation Accuracy: 87.870d% (8787/10000)
# train epoch[42/50]: 100%|██████████| 313/313 [00:13<00:00, 22.38it/s]
# valid epoch[42/50]: 100%|██████████| 79/79 [00:02<00:00, 28.18it/s]
# 	Training Loss: 0.937732 	Validation Loss: 1.114329
# 	Train Accuracy: 96.345d% (38538/40000)	Valdation Accuracy: 88.570d% (8857/10000)
# train epoch[43/50]: 100%|██████████| 313/313 [00:13<00:00, 22.48it/s]
# valid epoch[43/50]: 100%|██████████| 79/79 [00:02<00:00, 28.21it/s]
# 	Training Loss: 0.919659 	Validation Loss: 1.155283
# 	Train Accuracy: 96.683d% (38673/40000)	Valdation Accuracy: 88.390d% (8839/10000)
# train epoch[44/50]: 100%|██████████| 313/313 [00:13<00:00, 22.50it/s]
# valid epoch[44/50]: 100%|██████████| 79/79 [00:02<00:00, 28.60it/s]
# 	Training Loss: 0.928044 	Validation Loss: 1.172834
# 	Train Accuracy: 96.537d% (38615/40000)	Valdation Accuracy: 87.620d% (8762/10000)
# train epoch[45/50]: 100%|██████████| 313/313 [00:13<00:00, 22.49it/s]
# valid epoch[45/50]: 100%|██████████| 79/79 [00:02<00:00, 28.98it/s]
# 	Training Loss: 0.927058 	Validation Loss: 1.196051
# 	Train Accuracy: 96.567d% (38627/40000)	Valdation Accuracy: 87.170d% (8717/10000)
# train epoch[46/50]: 100%|██████████| 313/313 [00:13<00:00, 22.47it/s]
# valid epoch[46/50]: 100%|██████████| 79/79 [00:02<00:00, 28.71it/s]
# 	Training Loss: 0.924813 	Validation Loss: 1.139824
# 	Train Accuracy: 96.605d% (38642/40000)	Valdation Accuracy: 87.060d% (8706/10000)
# train epoch[47/50]: 100%|██████████| 313/313 [00:14<00:00, 22.34it/s]
# valid epoch[47/50]: 100%|██████████| 79/79 [00:02<00:00, 28.97it/s]
# 	Training Loss: 0.915256 	Validation Loss: 1.128084
# 	Train Accuracy: 96.882d% (38753/40000)	Valdation Accuracy: 87.330d% (8733/10000)
# train epoch[48/50]: 100%|██████████| 313/313 [00:13<00:00, 22.40it/s]
# valid epoch[48/50]: 100%|██████████| 79/79 [00:02<00:00, 28.86it/s]
# 	Training Loss: 0.911942 	Validation Loss: 1.125123
# 	Train Accuracy: 96.927d% (38771/40000)	Valdation Accuracy: 87.680d% (8768/10000)
# train epoch[49/50]: 100%|██████████| 313/313 [00:13<00:00, 22.53it/s]
# valid epoch[49/50]: 100%|██████████| 79/79 [00:02<00:00, 28.82it/s]
# 	Training Loss: 0.915265 	Validation Loss: 1.128145
# 	Train Accuracy: 96.938d% (38775/40000)	Valdation Accuracy: 87.860d% (8786/10000)
# train epoch[50/50]: 100%|██████████| 313/313 [00:13<00:00, 22.38it/s]
# valid epoch[50/50]: 100%|██████████| 79/79 [00:02<00:00, 28.64it/s]
# 	Training Loss: 0.904192 	Validation Loss: 1.133232
# 	Train Accuracy: 97.118d% (38847/40000)	Valdation Accuracy: 88.140d% (8814/10000)
# Finished Distilling

# %%
ftS_loss, ftS_accuracy = test(distiller_fe, test_loader, type='distiller', device=device)
# Out:
# test: 100%|██████████| 79/79 [00:02<00:00, 33.67it/s]
# test_loss: 1.244  test_accuracy: 88.650

# %% [markdown]
# ## Result and Comparison

# %%
print(f'Teacher from scratch: loss = {T_loss:.2f}, accuracy = {T_accuracy:.2f}')
print(f'Student from scratch: loss = {S_loss:.2f}, accuracy = {S_accuracy:.2f}')
print(f'Response-based student: loss = {reS_loss:.2f}, accuracy = {reS_accuracy:.2f}')
print(f'Featured-based student: loss = {ftS_loss:.2f}, accuracy = {ftS_accuracy:.2f}')
# Out:
# Teacher from scratch: loss = 0.46, accuracy = 89.84
# Student from scratch: loss = 0.51, accuracy = 87.50
# Response-based student: loss = 1.36, accuracy = 89.46
# Featured-based student: loss = 1.24, accuracy = 88.65
